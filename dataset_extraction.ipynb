# %%
# 1, covert the old patient database and labels to the new femr model format
# 2, structure of the dataset is: 
# {patient_id, sequence_meidcal_tokens, sequence_times_tokens, {task_name_1: {time_point_1, time_point_2, ...}, task_name_2: {time_point_1, time_point_2, ...}, ...}}

# %%
import pandas as pd
import numpy as np
import os
import json
from femr.datasets import PatientDatabase
import datetime
from tqdm import tqdm
from bisect import bisect_right, bisect_left
from ast import literal_eval

# %%
task_name_list =[
    "guo_los",
    "guo_readmission",
    "guo_icu",
    "new_hypertension",
    "new_hyperlipidemia",
    "new_pancan",
    "new_celiac",
    "new_lupus",
    "new_acutemi",
    "lab_thrombocytopenia",
    "lab_hyperkalemia",
    "lab_hyponatremia",
    "lab_anemia",
    "lab_hypoglycemia"
]
# 1, load the femr medical tokens, only keep the tokens that are with in the femr tokenizer
def load_medical_tokens(femr_token_dict_path = 'femr_vocab.json'):
    with open(femr_token_dict_path, 'r') as f:
        femr_dict = json.load(f)
    return femr_dict

# 2, load the patient database
def configure_database(path_to_database = "EHRSHOT_ASSETS/femr/extract"):
    return PatientDatabase(path_to_database)

# 3, load the patient labels and time
def load_patient_labels(path_to_labels_dir = "EHRSHOT_ASSETS/benchmark", task_dir = 'guo_los', label_file = 'labeled_patients.csv'):
    path_to_labels = os.path.join(path_to_labels_dir, task_dir, label_file)
    df_labels = pd.read_csv(path_to_labels)
    return df_labels

# 4, get the unique patient ids from a single label files. 
def get_unique_patient_ids(path_to_labels_dir = 'EHRSHOT_ASSETS/benchmark', task_dir = 'guo_los', label_file = 'labeled_patients.csv'):
    path_to_labels = os.path.join(path_to_labels_dir, task_dir, label_file)
    df_labels = pd.read_csv(path_to_labels)
    return list(df_labels['patient_id'].unique())

# 5, get the unique patient ids from all the label files.
def get_unique_patient_ids_all_tasks(path_to_labels_dir = 'EHRSHOT_ASSETS/benchmark', task_name_list = task_name_list, label_file = 'labeled_patients.csv'):
    patient_ids = []
    for task_name in task_name_list:
        current_patient_ids = get_unique_patient_ids(path_to_labels_dir, task_name, label_file)
        patient_ids.extend(current_patient_ids)
    return list(set(patient_ids))

# 6, given a patient id, extract the events, filter all the medical sequence that are in the femr tokenizer
def filter_medical_events(patient_id, database, femr_dict):
    patient_info = database[patient_id]
    assert patient_info.patient_id == patient_id
    event_list = database[patient_id].events
    patient_birthdate = database.get_patient_birth_date(patient_id)
    patient_birthdate = patient_birthdate.isoformat()

    medical_code_list = []
    time_list = []
    omop_person_info_list = []
    omop_time_info_list = []

    for i in range(len(event_list)):
        current_event = event_list[i]
        start_date = current_event.start
        start_date = start_date.isoformat()
        medical_code = current_event.code
        omop_table = current_event.omop_table
        if medical_code in femr_dict:
            medical_code_list.append(medical_code)
            time_list.append(start_date)
            assert start_date is not None
            assert medical_code is not None
        if omop_table == 'person':
            omop_person_info_list.append(medical_code)
            omop_time_info_list.append(start_date)
    
    patient = {}
    # patient['patient_id'] = patient_id
    patient['birth_date'] = patient_birthdate
    patient['medical_tokens'] = medical_code_list
    patient['time_tokens'] = time_list
    patient['person_info_tokens'] = omop_person_info_list
    patient['person_info_time_tokens'] = omop_time_info_list
    
    return patient

# 7, given a list of patient id, construct the dataset, return a dataframe with
def construct_dataset(patient_id_list, database, femr_dict, return_dataframe = True):
    dataset = {}
    for patient_id in tqdm(patient_id_list):
        patient_info = filter_medical_events(patient_id, database, femr_dict)
        dataset[patient_id] = patient_info
    if return_dataframe:
        dataset = pd.DataFrame(dataset).T
        dataset['patient_id'] = dataset.index
        dataset = dataset.reset_index(drop=True)
        return dataset
    else:
        return dataset

# 8, save the dataset with only patient id and 
def save_patient_dataset(patient_dataset, save_dir = 'new_femr_dataset/patient_info/'):
    for patient_id in tqdm(patient_dataset.keys()):
        patient_info = patient_dataset[patient_id]
        save_path = os.path.join(save_dir, str(patient_id) + '.json')
        with open(save_path, 'w') as f:
            json.dump(patient_info, f)

# 9, given a datatime string with format 
def convert_datetime_string_to_timestamp(datetime_string):
    date_format = '%Y-%m-%d %H:%M:%S'
    return datetime.datetime.strptime(datetime_string, date_format)

# 10, given patient's dataset, add the labels and the corresponding time points of a single medical task
def add_labels_to_dataset(dataset, path_to_labels_dir = 'EHRSHOT_ASSETS/benchmark', task_dir = 'guo_los', label_file = 'labeled_patients.csv'):
    path_to_labels = os.path.join(path_to_labels_dir, task_dir, label_file)
    df_labels = pd.read_csv(path_to_labels)
    for patient_id in tqdm(dataset.keys()):
        patient_info = dataset[patient_id]
        patient_info[task_dir] = {}

# 11, for a single task of a patient, given the input label dataframe of the patient, return the labe

# %%
femr_dict = load_medical_tokens()
database = configure_database("EHRSHOT_ASSETS/femr/extract")

# label_file = load_patient_labels(task_dir=task_name_list[0])
# patient_id_list = get_unique_patient_ids_all_tasks()
# patient_dataset = construct_dataset(patient_id_list, database, femr_dict, return_dataframe=False)
# save_patient_dataset(patient_dataset)

# df = pd.read_csv('patient_dataset.csv', converters={'medical_tokens': literal_eval, 'time_tokens': literal_eval, 'person_info_tokens': literal_eval, 'person_info_time_tokens': literal_eval})

# %%
len(os.listdir('new_femr_dataset/patient_info/'))
database[115967095].events
# Out:
# (Event(start=1933-12-22 00:00:00, code=SNOMED/3950001, value=None, =110267, omop_table=person),
#  Event(start=1933-12-22 23:59:00, code=Race/5, value=None, =80, omop_table=person),
#  Event(start=1933-12-22 23:59:00, code=Gender/F, value=None, =149, omop_table=person),
#  Event(start=1933-12-22 23:59:00, code=Ethnicity/Hispanic, value=None, =161558, omop_table=person),
#  Event(start=2008-10-07 23:40:00, code=LOINC/8480-6, value=116.0, =427208, omop_table=measurement),
#  Event(start=2008-10-07 23:40:00, code=LOINC/8462-4, value=58.0, =299869, omop_table=measurement),
#  Event(start=2008-10-07 23:40:00, code=LOINC/8310-5, value=98.5999984741211, =510293, omop_table=measurement),
#  Event(start=2008-10-07 23:40:00, code=LOINC/9279-1, value=16.0, =247313, omop_table=measurement),
#  Event(start=2008-10-07 23:40:00, code=LOINC/8327-9, value=1.0, =200894, omop_table=observation),
#  Event(start=2008-10-07 23:40:00, code=LOINC/8867-4, value=88.0, =362967, omop_table=measurement),
#  Event(start=2008-10-07 23:40:00, code=LOINC/8478-0, value=77.0, =339316, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-07 23:40:00, code=LOINC/LP21258-6, value=97.0, =388927, unit=%, omop_table=observation),
#  Event(start=2008-10-07 23:50:00, code=LOINC/IO_OUT, value=650.0, =495092, unit=ml, omop_table=measurement),
#  Event(start=2008-10-07 23:56:00, code=Visit/IP, value=None, =576, end=2008-10-15 10:50:00, visit_id=31251999.0, omop_table=visit_occurrence),
#  Event(start=2008-10-07 23:56:00, code=LOINC/34117-2, value=None, =58974, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-07 23:56:00, code=LOINC/34117-2, value=None, =59486, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-07 23:59:00, code=LOINC/3151-8, value=95.0, =377925, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=LOINC/8310-5, value=96.4000015258789, =505975, unit=F, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=LOINC/29463-7, value=1696.6600341796875, =588567, unit=ounces, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=LOINC/8302-2, value=62.0, =306438, unit=[in_us], visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=LOINC/39156-5, value=19.389999389648438, =589850, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=SNOMED/271649006, value=144.0, =448889, unit=mmHg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=SNOMED/271650006, value=80.0, =348552, unit=mmHg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=SNOMED/301898006, value=1.4500000476837158, =579269, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-07 23:59:00, code=SNOMED/78564009, value=102.0, =411579, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 00:30:00, code=RxNorm/1191222, value=None, =101198, end=2008-10-15 12:51:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:31:00, code=RxNorm/1795250, value=None, =106939, end=2008-10-08 03:12:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:33:00, code=RxNorm/311666, value=None, =85386, end=2008-10-15 12:51:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:33:00, code=RxNorm/1740467, value=None, =106059, end=2008-10-15 12:51:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:33:00, code=RxNorm/998212, value=None, =98519, end=2008-10-15 12:51:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:34:00, code=RxNorm/727517, value=None, =92976, end=2008-10-15 12:51:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:34:00, code=RxNorm/310520, value=None, =84179, end=2008-10-08 14:11:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 00:36:00, code=CPT4/80053, value=None, =8875, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 00:36:00, code=CPT4/85610, value=None, =12444, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 00:36:00, code=SNOMED/252465000, value=None, =141022, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 00:36:00, code=SNOMED/42525009, value=None, =115317, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 00:36:00, code=LOINC/69742-5, value=None, =70905, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 00:47:00, code=LOINC/8302-2, value=62.0, =305940, omop_table=measurement),
#  Event(start=2008-10-08 00:47:00, code=SNOMED/166900001, value=126.0, =436842, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:00:00, code=RxNorm/854228, value=None, =94391, end=2008-10-08 18:57:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 01:11:00, code=LOINC/718-7, value=9.699999809265137, =558443, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/731-0, value=2.119999885559082, =524249, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2345-7, value=102.0, =410269, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/20584-9, value=14.399999618530273, =588238, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/17861-6, value=7.300000190734863, =549100, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/1742-6, value=17.0, =249847, unit=U/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/770-8, value=80.5999984741211, =504222, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/786-4, value=33.79999923706055, =532021, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/713-8, value=0.699999988079071, =510300, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/5905-5, value=3.799999952316284, =528907, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/785-6, value=28.299999237060547, =600362, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/704-7, value=0.029999999329447746, =621105, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/751-8, value=11.579999923706055, =586489, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/3094-0, value=16.0, =246181, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/1920-8, value=33.0, =278227, unit=U/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/706-2, value=0.20000000298023224, =615593, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2075-0, value=104.0, =413635, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2028-9, value=24.0, =266808, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2160-0, value=0.800000011920929, =512700, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/14979-9, value=28.799999237060547, =601254, unit=sec, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2951-2, value=131.0, =441573, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/788-0, value=21.5, =263195, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/789-8, value=3.4200000762939453, =603642, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2885-2, value=4.900000095367432, =541882, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2336-6, value=3.799999952316284, =531872, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/6301-6, value=1.2000000476837158, =575895, unit=INR, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/2823-3, value=4.5, =215536, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/4544-3, value=28.700000762939453, =600303, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/787-2, value=83.9000015258789, =503972, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/1975-2, value=0.5, =195832, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/1751-7, value=1.100000023841858, =515826, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/777-3, value=195.0, =457825, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/711-2, value=0.10000000149011612, =614287, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/742-7, value=0.550000011920929, =510873, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/5902-2, value=14.199999809265137, =589493, unit=sec, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/6768-6, value=95.0, =379158, unit=U/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/736-9, value=14.699999809265137, =589248, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 01:11:00, code=LOINC/33037-3, value=3.0, =210050, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 02:43:00, code=LOINC/34117-2, value=None, =59523, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 03:12:00, code=RxNorm/615107, value=None, =91607, end=2008-10-09 10:14:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 03:18:00, code=SNOMED/60267001, value=None, =119406, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 04:03:00, code=LOINC/11210-2, value=20.0, =261070, unit=U/mL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 04:03:00, code=LOINC/2039-6, value=1.0, =197515, unit=ng/mL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 04:24:00, code=LOINC/LP173418-7, value=None, =129885, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 04:37:00, code=LOINC/24321-2, value=None, =46452, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 05:43:00, code=LOINC/8251-1, value=None, =30569, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/8480-6, value=115.0, =426360, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/8462-4, value=64.0, =310023, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/8310-5, value=98.19999694824219, =562620, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/9279-1, value=18.0, =254192, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/8327-9, value=1.0, =198825, omop_table=observation),
#  Event(start=2008-10-08 05:45:00, code=LOINC/8867-4, value=87.0, =360798, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/8478-0, value=81.0, =349440, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-08 05:45:00, code=LOINC/LP21258-6, value=99.0, =399619, unit=%, omop_table=observation),
#  Event(start=2008-10-08 05:59:00, code=SNOMED/166900001, value=175.0, =457043, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 06:00:00, code=LOINC/IO_OUT, value=600.0, =493742, unit=ml, omop_table=measurement),
#  Event(start=2008-10-08 07:17:00, code=LOINC/11506-3, value=None, =42279, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 07:56:00, code=LOINC/8480-6, value=113.0, =425367, omop_table=measurement),
#  Event(start=2008-10-08 07:56:00, code=LOINC/8462-4, value=50.0, =289235, omop_table=measurement),
#  Event(start=2008-10-08 07:56:00, code=LOINC/8310-5, value=96.30000305175781, =559809, omop_table=measurement),
#  Event(start=2008-10-08 07:56:00, code=LOINC/9279-1, value=16.0, =247720, omop_table=measurement),
#  Event(start=2008-10-08 07:56:00, code=LOINC/8867-4, value=88.0, =362771, omop_table=measurement),
#  Event(start=2008-10-08 07:56:00, code=LOINC/8478-0, value=71.0, =327485, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-08 08:00:00, code=LOINC/38214-3, value=0.0, =190002, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/718-7, value=9.399999618530273, =556838, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/731-0, value=2.0799999237060547, =590143, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/2345-7, value=146.0, =450771, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/20584-9, value=14.300000190734863, =589635, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/17861-6, value=7.0, =222152, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/770-8, value=80.9000015258789, =504920, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/786-4, value=33.70000076293945, =530971, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/5905-5, value=3.5, =212496, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/785-6, value=28.700000762939453, =600130, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/704-7, value=0.05000000074505806, =614484, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/751-8, value=11.529999732971191, =584806, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/3094-0, value=13.0, =238798, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/706-2, value=0.30000001192092896, =618704, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/2075-0, value=102.0, =409564, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/2028-9, value=22.0, =263488, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/2160-0, value=0.6000000238418579, =566515, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/788-0, value=21.299999237060547, =595039, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/789-8, value=3.2799999713897705, =601224, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/2823-3, value=4.699999809265137, =540330, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/4544-3, value=28.0, =272336, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/787-2, value=85.30000305175781, =555853, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/777-3, value=196.0, =457604, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/711-2, value=0.10999999940395355, =616194, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/742-7, value=0.5, =195257, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/736-9, value=14.600000381469727, =588919, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 08:10:00, code=LOINC/33037-3, value=7.0, =223686, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 09:56:00, code=LOINC/11506-3, value=None, =39394, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 09:56:00, code=LOINC/11506-3, value=None, =42420, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 11:14:00, code=LOINC/8480-6, value=110.0, =420828, omop_table=measurement),
#  Event(start=2008-10-08 11:14:00, code=LOINC/8310-5, value=97.9000015258789, =507032, omop_table=measurement),
#  Event(start=2008-10-08 11:14:00, code=LOINC/8867-4, value=84.0, =355896, omop_table=measurement),
#  Event(start=2008-10-08 11:14:00, code=LOINC/8478-0, value=70.0, =325673, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-08 11:14:00, code=LOINC/LP21258-6, value=100.0, =406435, unit=%, omop_table=observation),
#  Event(start=2008-10-08 12:01:00, code=SNOMED/166900001, value=166.0, =455026, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 12:04:00, code=LOINC/26453-1, value=None, =48400, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 12:04:00, code=SNOMED/116863004, value=None, =135165, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-08 12:10:00, code=RxNorm/313782, value=None, =88196, end=2008-10-08 15:54:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 12:10:00, code=RxNorm/1049909, value=None, =100141, end=2008-10-08 13:47:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 12:15:00, code=LOINC/890-4, value=Negative, =497542, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 12:15:00, code=LOINC/882-1, value=None, =23634, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 12:15:00, code=LOINC/51880-3, value=None, =66196, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 12:30:00, code=RxNorm/283100, value=None, =81512, end=2008-10-08 15:53:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 14:00:00, code=LOINC/IO_OUT, value=500.0, =487873, unit=ml, omop_table=measurement),
#  Event(start=2008-10-08 14:48:00, code=SNOMED/16742006, value=None, =111782, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 14:48:00, code=SNOMED/81228005, value=None, =122179, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 15:15:00, code=LOINC/77397-8, value=None, =74899, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 15:31:00, code=LOINC/8480-6, value=123.0, =434745, omop_table=measurement),
#  Event(start=2008-10-08 15:31:00, code=LOINC/8310-5, value=96.4000015258789, =505296, omop_table=measurement),
#  Event(start=2008-10-08 15:31:00, code=LOINC/9279-1, value=18.0, =252877, omop_table=measurement),
#  Event(start=2008-10-08 15:31:00, code=LOINC/8327-9, value=4.0, =213571, omop_table=observation),
#  Event(start=2008-10-08 15:31:00, code=LOINC/8478-0, value=74.0, =333758, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-08 15:41:00, code=SNOMED/116859006, value=None, =134791, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-08 16:27:00, code=SNOMED/166900001, value=213.0, =460101, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 17:00:00, code=RxNorm/242120, value=None, =80841, end=2008-10-13 23:01:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 17:42:00, code=LOINC/LP173418-7, value=None, =130396, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 18:00:00, code=LOINC/8480-6, value=118.0, =428899, omop_table=measurement),
#  Event(start=2008-10-08 18:00:00, code=LOINC/8462-4, value=76.0, =336580, omop_table=measurement),
#  Event(start=2008-10-08 18:00:00, code=LOINC/8310-5, value=97.19999694824219, =560158, omop_table=measurement),
#  Event(start=2008-10-08 18:00:00, code=LOINC/8327-9, value=1.0, =200543, omop_table=observation),
#  Event(start=2008-10-08 18:00:00, code=LOINC/8867-4, value=83.0, =353706, omop_table=measurement),
#  Event(start=2008-10-08 18:00:00, code=LOINC/8478-0, value=90.0, =367592, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/718-7, value=10.399999618530273, =583736, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/731-0, value=2.0, =206318, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/20584-9, value=12.100000381469727, =587889, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/770-8, value=78.5999984741211, =503737, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/786-4, value=32.400001525878906, =607047, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/713-8, value=0.800000011920929, =512754, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/5905-5, value=3.700000047683716, =528713, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/785-6, value=28.399999618530273, =600919, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/751-8, value=9.529999732971191, =557477, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/706-2, value=0.4000000059604645, =564625, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/3255-7, value=281.0, =464653, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/14979-9, value=29.299999237060547, =599563, unit=sec, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/788-0, value=17.5, =251447, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/789-8, value=3.680000066757202, =527881, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/4544-3, value=32.29999923706055, =531061, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/787-2, value=87.69999694824219, =556440, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/777-3, value=59.0, =300292, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/711-2, value=0.10000000149011612, =615925, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/742-7, value=0.44999998807907104, =619002, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/5902-2, value=14.300000190734863, =587718, unit=sec, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 18:45:00, code=LOINC/736-9, value=16.5, =249635, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 19:00:00, code=RxNorm/24912, value=None, =33362, end=2008-10-08 20:12:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-08 19:25:00, code=LOINC/11506-3, value=None, =40514, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-08 19:29:00, code=SNOMED/115267000, value=None, =134179, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-08 21:00:00, code=SNOMED/250346004, value=None, =140520, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 21:33:00, code=SNOMED/166900001, value=193.0, =457451, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 22:00:00, code=LOINC/IO_OUT, value=350.0, =470693, unit=ml, omop_table=measurement),
#  Event(start=2008-10-08 23:12:00, code=LOINC/8480-6, value=123.0, =434666, omop_table=measurement),
#  Event(start=2008-10-08 23:12:00, code=LOINC/8462-4, value=53.0, =293156, omop_table=measurement),
#  Event(start=2008-10-08 23:12:00, code=LOINC/8867-4, value=79.0, =344243, omop_table=measurement),
#  Event(start=2008-10-08 23:12:00, code=LOINC/8478-0, value=76.0, =337866, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-08 23:12:00, code=LOINC/LP21258-6, value=97.0, =390060, unit=%, omop_table=observation),
#  Event(start=2008-10-08 23:20:00, code=LOINC/718-7, value=9.899999618530273, =558619, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/731-0, value=2.1700000762939453, =591452, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/20584-9, value=14.399999618530273, =588594, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/770-8, value=80.0, =345320, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/786-4, value=32.900001525878906, =607224, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/713-8, value=0.699999988079071, =511138, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/785-6, value=28.5, =273950, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/704-7, value=0.07000000029802322, =614982, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/751-8, value=11.5, =236003, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/706-2, value=0.5, =195058, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/788-0, value=21.0, =261070, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/789-8, value=3.4700000286102295, =603209, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/4544-3, value=30.100000381469727, =605197, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/787-2, value=86.69999694824219, =556406, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/777-3, value=194.0, =458212, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/742-7, value=0.5299999713897705, =565834, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:20:00, code=LOINC/736-9, value=15.100000381469727, =589712, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/110483000, value=None, =132913, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/228490006, value=N, =173118, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/228510007, value=N, =175386, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/230056004, value=N, =177363, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/230058003, value=N, =180910, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/230057008, value=N, =178473, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/417662000, value=None, =147897, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/387713003, value=None, =145748, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-08 23:59:00, code=SNOMED/713914004, value=None, =154368, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-08 23:59:00, code=Medicare Specialty/A0, value=None, =166811, end=2008-10-08 23:59:00, visit_id=31255748.0, omop_table=visit_occurrence),
#  Event(start=2008-10-08 23:59:00, code=LOINC/72166-2, value=None, =73610, visit_id=31255748.0, omop_table=observation),
#  Event(start=2008-10-09 03:44:00, code=LOINC/8480-6, value=128.0, =437184, omop_table=measurement),
#  Event(start=2008-10-09 03:44:00, code=LOINC/8462-4, value=62.0, =306985, omop_table=measurement),
#  Event(start=2008-10-09 03:44:00, code=LOINC/8310-5, value=96.5999984741211, =506104, omop_table=measurement),
#  Event(start=2008-10-09 03:44:00, code=LOINC/9279-1, value=18.0, =253763, omop_table=measurement),
#  Event(start=2008-10-09 03:44:00, code=LOINC/8327-9, value=1.0, =200889, omop_table=observation),
#  Event(start=2008-10-09 03:44:00, code=LOINC/8867-4, value=81.0, =349389, omop_table=measurement),
#  Event(start=2008-10-09 03:44:00, code=LOINC/8478-0, value=84.0, =354493, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-09 03:44:00, code=LOINC/LP21258-6, value=99.0, =400029, unit=%, omop_table=observation),
#  Event(start=2008-10-09 05:05:00, code=LOINC/718-7, value=10.300000190734863, =584162, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/731-0, value=2.0899999141693115, =591912, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/2345-7, value=160.0, =452909, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/20584-9, value=16.399999618530273, =590015, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/17861-6, value=7.199999809265137, =550664, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/770-8, value=83.30000305175781, =554656, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/786-4, value=34.79999923706055, =532320, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/713-8, value=0.699999988079071, =512030, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/5905-5, value=2.799999952316284, =526580, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/785-6, value=29.5, =274318, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/704-7, value=0.07000000029802322, =613480, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/751-8, value=13.619999885559082, =587409, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/3094-0, value=11.0, =233528, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/706-2, value=0.4000000059604645, =564974, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/2075-0, value=103.0, =411872, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/2028-9, value=22.0, =263457, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/2160-0, value=0.699999988079071, =510633, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/2951-2, value=131.0, =440204, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/788-0, value=20.799999237060547, =595407, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/789-8, value=3.4700000286102295, =603117, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/2823-3, value=4.599999904632568, =538779, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/4544-3, value=29.5, =274630, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/787-2, value=84.9000015258789, =503982, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/777-3, value=196.0, =457625, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/711-2, value=0.11999999731779099, =615235, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/742-7, value=0.46000000834465027, =617903, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/736-9, value=12.800000190734863, =586681, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 05:05:00, code=LOINC/33037-3, value=6.0, =220041, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 06:00:00, code=LOINC/IO_OUT, value=700.0, =496775, unit=ml, omop_table=measurement),
#  Event(start=2008-10-09 06:44:00, code=LOINC/11506-3, value=None, =39449, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 06:49:00, code=SNOMED/166900001, value=176.0, =455434, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 06:55:00, code=LOINC/8251-1, value=None, =31995, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 07:01:00, code=LOINC/LP173418-7, value=None, =126852, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 07:53:00, code=LOINC/8480-6, value=122.0, =433390, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/8462-4, value=61.0, =304947, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/8310-5, value=96.30000305175781, =557705, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/9279-1, value=16.0, =247297, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/8867-4, value=90.0, =367403, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/8478-0, value=81.0, =348665, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/38214-3, value=0.0, =191835, omop_table=measurement),
#  Event(start=2008-10-09 07:53:00, code=LOINC/LP21258-6, value=96.0, =384774, unit=%, omop_table=observation),
#  Event(start=2008-10-09 07:55:00, code=RxNorm/242120, value=None, =80666, end=2008-10-09 07:55:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-09 08:00:00, code=RxNorm/1740467, value=None, =106477, end=2008-10-09 08:00:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-09 09:17:00, code=LOINC/11488-4, value=None, =33855, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 10:14:00, code=LOINC/34800-3, value=None, =64064, visit_id=31251999.0, omop_table=observation),
#  Event(start=2008-10-09 10:15:00, code=LOINC/28570-0, value=None, =52485, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 10:16:00, code=RxNorm/313782, value=None, =88178, end=2008-10-09 11:31:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-09 10:16:00, code=SNOMED/116863004, value=None, =135179, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-09 10:16:00, code=RxNorm/1049909, value=None, =100251, end=2008-10-09 11:32:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-09 10:17:00, code=CPT4/85027, value=None, =11869, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 11:05:00, code=SNOMED/116859006, value=None, =135193, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-09 11:14:00, code=SNOMED/166900001, value=249.0, =462121, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 11:58:00, code=LOINC/8480-6, value=135.0, =443231, omop_table=measurement),
#  Event(start=2008-10-09 11:58:00, code=LOINC/8462-4, value=64.0, =310954, omop_table=measurement),
#  Event(start=2008-10-09 11:58:00, code=LOINC/8310-5, value=97.30000305175781, =560992, omop_table=measurement),
#  Event(start=2008-10-09 11:58:00, code=LOINC/8867-4, value=85.0, =358372, omop_table=measurement),
#  Event(start=2008-10-09 11:58:00, code=LOINC/8478-0, value=88.0, =362441, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-09 11:58:00, code=LOINC/LP21258-6, value=99.0, =400437, unit=%, omop_table=observation),
#  Event(start=2008-10-09 12:45:00, code=LOINC/IO_OUT, value=250.0, =461986, unit=ml, omop_table=measurement),
#  Event(start=2008-10-09 13:00:00, code=LOINC/IO_OUT, value=275.0, =465803, unit=ml, omop_table=measurement),
#  Event(start=2008-10-09 14:00:00, code=LOINC/8480-6, value=122.0, =433608, omop_table=measurement),
#  Event(start=2008-10-09 14:00:00, code=LOINC/8310-5, value=97.69999694824219, =560181, omop_table=measurement),
#  Event(start=2008-10-09 14:00:00, code=LOINC/9279-1, value=18.0, =254402, omop_table=measurement),
#  Event(start=2008-10-09 14:00:00, code=LOINC/8867-4, value=83.0, =353024, omop_table=measurement),
#  Event(start=2008-10-09 14:00:00, code=LOINC/LP21258-6, value=98.0, =396167, unit=%, omop_table=observation),
#  Event(start=2008-10-09 14:34:00, code=SNOMED/43396009, value=None, =116209, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 15:49:00, code=LOINC/8480-6, value=129.0, =439330, omop_table=measurement),
#  Event(start=2008-10-09 15:49:00, code=LOINC/8462-4, value=69.0, =320967, omop_table=measurement),
#  Event(start=2008-10-09 15:49:00, code=LOINC/9279-1, value=20.0, =259918, omop_table=measurement),
#  Event(start=2008-10-09 15:49:00, code=LOINC/8867-4, value=84.0, =356229, omop_table=measurement),
#  Event(start=2008-10-09 15:49:00, code=LOINC/8478-0, value=89.0, =363940, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-09 16:26:00, code=LOINC/11506-3, value=None, =38389, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 16:44:00, code=SNOMED/166900001, value=168.0, =455974, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 16:45:00, code=LOINC/11488-4, value=None, =34105, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 17:48:00, code=LOINC/LP173418-7, value=None, =127370, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-09 19:30:00, code=LOINC/718-7, value=12.300000190734863, =586390, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/4548-4, value=5.900000095367432, =544346, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/20584-9, value=18.899999618530273, =591799, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/786-4, value=34.0, =278661, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/785-6, value=29.100000381469727, =601284, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/788-0, value=19.200000762939453, =592185, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/789-8, value=4.21999979019165, =503019, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/4544-3, value=36.20000076293945, =532246, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/787-2, value=85.69999694824219, =557142, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 19:30:00, code=LOINC/777-3, value=212.0, =460508, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 20:00:00, code=RxNorm/106258, value=None, =75556, end=2008-10-15 12:51:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-09 21:10:00, code=SNOMED/166900001, value=131.0, =439933, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 22:00:00, code=LOINC/24321-2, value=None, =46600, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 22:00:00, code=LOINC/69742-5, value=None, =71150, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-09 22:00:00, code=LOINC/IO_OUT, value=450.0, =481743, unit=ml, omop_table=measurement),
#  Event(start=2008-10-09 23:48:00, code=LOINC/8480-6, value=118.0, =430134, omop_table=measurement),
#  Event(start=2008-10-09 23:48:00, code=LOINC/8462-4, value=57.0, =298115, omop_table=measurement),
#  Event(start=2008-10-09 23:48:00, code=LOINC/8310-5, value=96.80000305175781, =560483, omop_table=measurement),
#  Event(start=2008-10-09 23:48:00, code=LOINC/8867-4, value=87.0, =360845, omop_table=measurement),
#  Event(start=2008-10-09 23:48:00, code=LOINC/8478-0, value=77.0, =338955, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-09 23:48:00, code=LOINC/LP21258-6, value=95.0, =382135, unit=%, omop_table=observation),
#  Event(start=2008-10-09 23:59:00, code=RxNorm/854228, value=None, =94034, end=2008-10-09 23:59:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-10 05:00:00, code=LOINC/IO_OUT, value=500.0, =489286, unit=ml, omop_table=measurement),
#  Event(start=2008-10-10 05:04:00, code=LOINC/LP173418-7, value=None, =130631, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-10 06:05:00, code=LOINC/718-7, value=12.199999809265137, =584822, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/731-0, value=2.25, =259097, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/2345-7, value=120.0, =431932, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/20584-9, value=22.299999237060547, =595236, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/17861-6, value=6.900000095367432, =549286, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/770-8, value=86.30000305175781, =555228, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/786-4, value=34.20000076293945, =532744, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/713-8, value=0.4000000059604645, =565715, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/5905-5, value=2.9000000953674316, =595501, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/785-6, value=29.399999618530273, =599652, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/704-7, value=0.07999999821186066, =613429, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/751-8, value=19.25, =459006, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/3094-0, value=10.0, =231076, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/706-2, value=0.30000001192092896, =617348, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/2075-0, value=98.0, =392201, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/2028-9, value=25.0, =268082, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/2160-0, value=0.6000000238418579, =566885, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/2951-2, value=131.0, =439229, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/788-0, value=19.399999618530273, =591435, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/789-8, value=4.130000114440918, =535972, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/2823-3, value=4.800000190734863, =539178, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/4544-3, value=35.5, =279728, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/787-2, value=85.9000015258789, =504925, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/777-3, value=223.0, =459546, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/711-2, value=0.10000000149011612, =615434, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/742-7, value=0.6399999856948853, =570500, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/736-9, value=10.100000381469727, =583910, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:05:00, code=LOINC/33037-3, value=8.0, =226005, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 06:23:00, code=SNOMED/115267000, value=None, =134500, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-10 06:30:00, code=LOINC/11506-3, value=None, =40614, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-10 07:16:00, code=LOINC/36643-5, value=None, =64671, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-10 07:30:00, code=RxNorm/1807628, value=None, =108423, end=2008-10-10 09:30:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-10 07:31:00, code=LOINC/8480-6, value=137.0, =445933, omop_table=measurement),
#  Event(start=2008-10-10 07:31:00, code=LOINC/8462-4, value=69.0, =321539, omop_table=measurement),
#  Event(start=2008-10-10 07:31:00, code=LOINC/8310-5, value=97.5, =391004, omop_table=measurement),
#  Event(start=2008-10-10 07:31:00, code=LOINC/9279-1, value=18.0, =252440, omop_table=measurement),
#  Event(start=2008-10-10 07:31:00, code=LOINC/8327-9, value=1.0, =199600, omop_table=observation),
#  Event(start=2008-10-10 07:31:00, code=LOINC/8867-4, value=84.0, =354590, omop_table=measurement),
#  Event(start=2008-10-10 07:31:00, code=LOINC/8478-0, value=92.0, =370961, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-10 07:31:00, code=LOINC/LP21258-6, value=95.0, =380905, unit=%, omop_table=observation),
#  Event(start=2008-10-10 09:30:00, code=RxNorm/106258, value=None, =75658, end=2008-10-10 09:30:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-10 10:58:00, code=SNOMED/166900001, value=182.0, =456880, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-10 11:00:00, code=RxNorm/242120, value=None, =80814, end=2008-10-10 11:00:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-10 11:32:00, code=LOINC/8480-6, value=136.0, =444133, omop_table=measurement),
#  Event(start=2008-10-10 11:32:00, code=LOINC/8462-4, value=63.0, =309800, omop_table=measurement),
#  Event(start=2008-10-10 11:32:00, code=LOINC/8310-5, value=97.0, =387094, omop_table=measurement),
#  Event(start=2008-10-10 11:32:00, code=LOINC/8867-4, value=80.0, =347289, omop_table=measurement),
# ...
#  Event(start=2008-10-14 06:25:00, code=LOINC/731-0, value=2.0, =207217, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/2345-7, value=265.0, =462953, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/20584-9, value=19.600000381469727, =590890, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/17861-6, value=7.599999904632568, =551108, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/770-8, value=86.0, =357831, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/786-4, value=34.099998474121094, =607198, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/713-8, value=0.0, =183199, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/5905-5, value=3.5999999046325684, =602629, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/785-6, value=29.899999618530273, =601830, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/704-7, value=0.03999999910593033, =612869, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/751-8, value=16.8700008392334, =504132, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/3094-0, value=19.0, =256557, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/706-2, value=0.20000000298023224, =616522, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/2075-0, value=97.0, =386412, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/2028-9, value=26.0, =270312, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/2160-0, value=0.699999988079071, =511933, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/2951-2, value=128.0, =436891, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/788-0, value=20.600000381469727, =595757, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/789-8, value=3.5199999809265137, =601645, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/2823-3, value=4.599999904632568, =539916, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/4544-3, value=30.899999618530273, =604594, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/787-2, value=87.69999694824219, =557429, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/777-3, value=269.0, =463268, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/711-2, value=0.009999999776482582, =621077, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/742-7, value=0.7099999785423279, =569488, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/736-9, value=10.199999809265137, =585154, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 06:25:00, code=LOINC/33037-3, value=5.0, =217073, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 07:32:00, code=LOINC/8462-4, value=64.0, =311871, omop_table=measurement),
#  Event(start=2008-10-14 07:32:00, code=LOINC/8310-5, value=97.19999694824219, =558705, omop_table=measurement),
#  Event(start=2008-10-14 07:32:00, code=LOINC/9279-1, value=22.0, =264000, omop_table=measurement),
#  Event(start=2008-10-14 07:32:00, code=LOINC/8867-4, value=85.0, =357989, omop_table=measurement),
#  Event(start=2008-10-14 07:32:00, code=LOINC/8478-0, value=84.0, =355000, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-14 09:00:00, code=RxNorm/106258, value=None, =76082, end=2008-10-14 09:00:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-14 09:00:00, code=RxNorm/1807628, value=None, =109189, end=2008-10-14 09:00:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-14 09:08:00, code=RxNorm/314216, value=None, =89498, end=2008-10-14 09:08:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-14 09:08:00, code=RxNorm/313782, value=None, =88654, end=2008-10-14 09:08:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-14 09:22:00, code=LOINC/11506-3, value=None, =40095, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 09:45:00, code=LOINC/38214-3, value=0.0, =193486, omop_table=measurement),
#  Event(start=2008-10-14 11:09:00, code=SNOMED/166900001, value=323.0, =466991, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 14:00:00, code=LOINC/IO_OUT, value=400.0, =474977, unit=ml, omop_table=measurement),
#  Event(start=2008-10-14 14:18:00, code=SNOMED/166900001, value=234.0, =461683, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 15:02:00, code=LOINC/LP173418-7, value=None, =129621, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 15:27:00, code=LOINC/11488-4, value=None, =35148, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 15:28:00, code=LOINC/11506-3, value=None, =40414, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 15:35:00, code=LOINC/8462-4, value=63.0, =309520, omop_table=measurement),
#  Event(start=2008-10-14 15:35:00, code=LOINC/8310-5, value=96.0999984741211, =504903, omop_table=measurement),
#  Event(start=2008-10-14 15:35:00, code=LOINC/9279-1, value=20.0, =259499, omop_table=measurement),
#  Event(start=2008-10-14 15:35:00, code=LOINC/8867-4, value=87.0, =361349, omop_table=measurement),
#  Event(start=2008-10-14 15:35:00, code=LOINC/8478-0, value=83.0, =352602, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-14 15:35:00, code=LOINC/LP21258-6, value=96.0, =384093, unit=%, omop_table=observation),
#  Event(start=2008-10-14 15:37:00, code=LOINC/11507-1, value=None, =43395, visit_id=31251999.0, omop_table=observation),
#  Event(start=2008-10-14 15:40:00, code=SNOMED/709542007, value=None, =153733, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-14 15:41:00, code=SNOMED/182922004, value=None, =138630, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-14 15:59:00, code=LOINC/11506-3, value=None, =39772, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 16:42:00, code=SNOMED/166900001, value=155.0, =452979, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 17:10:00, code=LOINC/LP173418-7, value=None, =128148, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 17:10:00, code=LOINC/18842-5, value=None, =44816, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 17:10:00, code=LOINC/42344-2, value=None, =65060, visit_id=31251999.0, omop_table=observation),
#  Event(start=2008-10-14 17:10:00, code=SNOMED/398636004, value=None, =145898, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2008-10-14 17:50:00, code=LOINC/LP173418-7, value=None, =126701, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 21:23:00, code=SNOMED/166900001, value=207.0, =458646, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 21:53:00, code=LOINC/IO_OUT, value=300.0, =465083, unit=ml, omop_table=measurement),
#  Event(start=2008-10-14 22:00:00, code=LOINC/24321-2, value=None, =46313, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 22:00:00, code=LOINC/69742-5, value=None, =71255, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-14 23:46:00, code=LOINC/LP173418-7, value=None, =128079, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-14 23:59:00, code=SNOMED/22741003, value=None, =112621, end=2008-10-14 23:59:00, omop_table=condition_occurrence),
#  Event(start=2008-10-15 00:01:00, code=LOINC/8480-6, value=134.0, =442392, omop_table=measurement),
#  Event(start=2008-10-15 00:01:00, code=LOINC/8462-4, value=65.0, =312796, omop_table=measurement),
#  Event(start=2008-10-15 00:01:00, code=LOINC/8310-5, value=96.30000305175781, =558288, omop_table=measurement),
#  Event(start=2008-10-15 00:01:00, code=LOINC/9279-1, value=18.0, =255669, omop_table=measurement),
#  Event(start=2008-10-15 00:01:00, code=LOINC/8327-9, value=1.0, =199602, omop_table=observation),
#  Event(start=2008-10-15 00:01:00, code=LOINC/8867-4, value=91.0, =370240, omop_table=measurement),
#  Event(start=2008-10-15 00:01:00, code=LOINC/8478-0, value=88.0, =363292, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-15 00:01:00, code=LOINC/LP21258-6, value=97.0, =389658, unit=%, omop_table=observation),
#  Event(start=2008-10-15 02:28:00, code=RxNorm/998212, value=None, =98473, end=2008-10-15 02:28:46, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-15 03:00:00, code=LOINC/38214-3, value=0.0, =191065, omop_table=measurement),
#  Event(start=2008-10-15 04:03:00, code=LOINC/IO_OUT, value=350.0, =468576, unit=ml, omop_table=measurement),
#  Event(start=2008-10-15 06:00:00, code=Domain/OMOP generated, value=None, =167018, end=2008-10-15 06:00:00, visit_id=31315593.0, omop_table=visit_occurrence),
#  Event(start=2008-10-15 06:00:00, code=SNOMED/166900001, value=141.0, =448577, unit=mg/dL, visit_id=31315593.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/718-7, value=11.399999618530273, =584051, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/731-0, value=2.3399999141693115, =592682, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/2345-7, value=132.0, =440340, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/20584-9, value=16.600000381469727, =590106, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/17861-6, value=7.699999809265137, =551605, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/770-8, value=79.80000305175781, =553864, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/786-4, value=34.0, =278998, unit=g/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/713-8, value=0.6000000238418579, =568548, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/5905-5, value=5.199999809265137, =542364, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/785-6, value=29.600000381469727, =599805, unit=pg, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/704-7, value=0.05000000074505806, =612059, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/751-8, value=13.270000457763672, =589024, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/3094-0, value=17.0, =250574, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/706-2, value=0.30000001192092896, =618511, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/2075-0, value=95.0, =379129, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/2028-9, value=28.0, =272760, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/2160-0, value=0.800000011920929, =513707, unit=mg/dL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/2951-2, value=129.0, =438378, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/788-0, value=20.299999237060547, =594576, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/789-8, value=3.8399999141693115, =603476, unit=MIL/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/2823-3, value=4.699999809265137, =539803, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/4544-3, value=33.400001525878906, =606450, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/787-2, value=87.0999984741211, =504761, unit=fL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/777-3, value=287.0, =463389, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/711-2, value=0.10000000149011612, =614972, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/742-7, value=0.8700000047683716, =570184, unit=K/uL, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/736-9, value=14.100000381469727, =589273, unit=%, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 06:05:00, code=LOINC/33037-3, value=6.0, =220116, unit=mmol/L, visit_id=31251999.0, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/8480-6, value=144.0, =448369, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/8462-4, value=80.0, =346071, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/8310-5, value=96.4000015258789, =505896, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/8867-4, value=102.0, =410149, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/8478-0, value=101.0, =408348, unit=mmHg, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/38214-3, value=5.0, =217772, omop_table=measurement),
#  Event(start=2008-10-15 08:28:00, code=LOINC/LP21258-6, value=95.0, =381200, unit=%, omop_table=observation),
#  Event(start=2008-10-15 08:33:00, code=RxNorm/106258, value=None, =76258, end=2008-10-15 08:33:04, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-10-15 09:00:00, code=LOINC/LP173418-7, value=None, =127545, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-15 09:00:00, code=LOINC/IO_OUT, value=500.0, =488475, unit=ml, omop_table=measurement),
#  Event(start=2008-10-15 09:26:00, code=LOINC/11506-3, value=None, =36481, visit_id=31251999.0, omop_table=note),
#  Event(start=2008-10-15 09:30:00, code=LOINC/38214-3, value=0.0, =190668, omop_table=measurement),
#  Event(start=2008-10-15 10:30:00, code=LOINC/38214-3, value=2.0, =208363, omop_table=measurement),
#  Event(start=2008-10-15 10:38:00, code=SNOMED/287761000000107, value=None, =169245, visit_id=31251999.0, omop_table=observation),
#  Event(start=2008-10-15 10:50:00, code=SNOMED/22741003, value=None, =112452, visit_id=31251999.0, omop_table=condition_occurrence),
#  Event(start=2008-10-15 11:07:00, code=LOINC/8251-1, value=None, =31493, visit_id=31315593.0, omop_table=measurement),
#  Event(start=2008-10-15 23:59:00, code=RxNorm/1049221, value=None, =99717, end=2009-04-13 23:59:00, visit_id=31251999.0, omop_table=drug_exposure),
#  Event(start=2008-11-03 14:34:00, code=SNOMED/116859006, value=None, =134697, visit_id=31251999.0, omop_table=procedure_occurrence),
#  Event(start=2009-04-25 16:29:00, code=LOINC/11506-3, value=None, =37844, visit_id=31275860.0, omop_table=note))

# %%
a = patient_dataset[115967095]

# %%
d = patient_dataset[115967096]['person_info_time_tokens'][0]
print(d)
d_i = d.isoformat()
print(d_i)
d_j = datetime.datetime.fromisoformat(d_i)
assert d == d_j
# Out:
# 1940-06-24 00:00:00
# 1940-06-24T00:00:00

# %%
with open('new_femr_dataset/temp.json', 'w') as f:
    json.dump(a, f)

# %%
patient_dataset.head(5)
# Out:
#    birth_date                                     medical_tokens  \
# 0  1933-12-22  ['Race/5', 'Gender/F', 'Ethnicity/Hispanic', '...
# 1  1940-06-24  ['Race/5', 'Gender/F', 'Ethnicity/Not Hispanic...
# 2  1957-08-10  ['Race/5', 'Gender/F', 'Ethnicity/Not Hispanic...
# 3  1943-12-15  ['Race/5', 'Gender/F', 'Ethnicity/Not Hispanic...
# 4  1952-03-03  ['Race/5', 'Gender/F', 'Ethnicity/Not Hispanic...
#
#                                          time_tokens  \
# 0  [datetime.datetime(1933, 12, 22, 23, 59), date...
# 1  [datetime.datetime(1940, 6, 24, 23, 59), datet...
# 2  [datetime.datetime(1957, 8, 10, 23, 59), datet...
# 3  [datetime.datetime(1943, 12, 15, 23, 59), date...
# 4  [datetime.datetime(1952, 3, 3, 23, 59), dateti...
#
#                                   person_info_tokens  \
# 0  ['SNOMED/3950001', 'Race/5', 'Gender/F', 'Ethn...
# 1  ['SNOMED/3950001', 'Race/5', 'Gender/F', 'Ethn...
# 2  ['SNOMED/3950001', 'Race/5', 'Gender/F', 'Ethn...
# 3  ['SNOMED/3950001', 'Race/5', 'Gender/F', 'Ethn...
# 4  ['SNOMED/3950001', 'Race/5', 'Gender/F', 'Ethn...
#
#                              person_info_time_tokens  patient_id
# 0  [datetime.datetime(1933, 12, 22, 0, 0), dateti...   115967095
# 1  [datetime.datetime(1940, 6, 24, 0, 0), datetim...   115967096
# 2  [datetime.datetime(1957, 8, 10, 0, 0), datetim...   115967097
# 3  [datetime.datetime(1943, 12, 15, 0, 0), dateti...   115967098
# 4  [datetime.datetime(1952, 3, 3, 0, 0), datetime...   115967099

# %%
patient_dataset.loc[0]['time_tokens'], type(patient_dataset.loc[0]['time_tokens'][0])
# Out:
# ('[datetime.datetime(1933, 12, 22, 23, 59), datetime.datetime(1933, 12, 22, 23, 59), datetime.datetime(1933, 12, 22, 23, 59), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 40), datetime.datetime(2008, 10, 7, 23, 50), datetime.datetime(2008, 10, 7, 23, 56), datetime.datetime(2008, 10, 7, 23, 56), datetime.datetime(2008, 10, 7, 23, 56), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 7, 23, 59), datetime.datetime(2008, 10, 8, 0, 30), datetime.datetime(2008, 10, 8, 0, 31), datetime.datetime(2008, 10, 8, 0, 33), datetime.datetime(2008, 10, 8, 0, 33), datetime.datetime(2008, 10, 8, 0, 33), datetime.datetime(2008, 10, 8, 0, 34), datetime.datetime(2008, 10, 8, 0, 34), datetime.datetime(2008, 10, 8, 0, 36), datetime.datetime(2008, 10, 8, 0, 36), datetime.datetime(2008, 10, 8, 0, 36), datetime.datetime(2008, 10, 8, 0, 36), datetime.datetime(2008, 10, 8, 0, 36), datetime.datetime(2008, 10, 8, 0, 47), datetime.datetime(2008, 10, 8, 0, 47), datetime.datetime(2008, 10, 8, 1, 0), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 1, 11), datetime.datetime(2008, 10, 8, 2, 43), datetime.datetime(2008, 10, 8, 3, 12), datetime.datetime(2008, 10, 8, 3, 18), datetime.datetime(2008, 10, 8, 4, 3), datetime.datetime(2008, 10, 8, 4, 3), datetime.datetime(2008, 10, 8, 4, 24), datetime.datetime(2008, 10, 8, 4, 37), datetime.datetime(2008, 10, 8, 5, 43), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 45), datetime.datetime(2008, 10, 8, 5, 59), datetime.datetime(2008, 10, 8, 6, 0), datetime.datetime(2008, 10, 8, 7, 17), datetime.datetime(2008, 10, 8, 7, 56), datetime.datetime(2008, 10, 8, 7, 56), datetime.datetime(2008, 10, 8, 7, 56), datetime.datetime(2008, 10, 8, 7, 56), datetime.datetime(2008, 10, 8, 7, 56), datetime.datetime(2008, 10, 8, 7, 5 ...
#  str)

# %%
path_to_database = 'EHRSHOT_ASSETS/femr/extract'
path_to_dataset = 'patient_dataset.csv'
path_to_medical_tokens = 'femr_vocab.json'
path_to_labels_dir = 'EHRSHOT_ASSETS/benchmark'

femr_dict = load_medical_tokens(femr_token_dict_path=path_to_medical_tokens)
database = configure_database(path_to_database)
patient_id_list = get_unique_patient_ids_all_tasks(path_to_labels_dir=path_to_labels_dir)
patient_dataset = construct_dataset(patient_id_list, database, femr_dict)
# Out:
# 100%|██████████| 6275/6275 [05:01<00:00, 20.84it/s]

# %%
patient_dataset.loc[0]['time_tokens']
# Out:
# [datetime.datetime(1933, 12, 22, 23, 59),
#  datetime.datetime(1933, 12, 22, 23, 59),
#  datetime.datetime(1933, 12, 22, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 40),
#  datetime.datetime(2008, 10, 7, 23, 50),
#  datetime.datetime(2008, 10, 7, 23, 56),
#  datetime.datetime(2008, 10, 7, 23, 56),
#  datetime.datetime(2008, 10, 7, 23, 56),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 7, 23, 59),
#  datetime.datetime(2008, 10, 8, 0, 30),
#  datetime.datetime(2008, 10, 8, 0, 31),
#  datetime.datetime(2008, 10, 8, 0, 33),
#  datetime.datetime(2008, 10, 8, 0, 33),
#  datetime.datetime(2008, 10, 8, 0, 33),
#  datetime.datetime(2008, 10, 8, 0, 34),
#  datetime.datetime(2008, 10, 8, 0, 34),
#  datetime.datetime(2008, 10, 8, 0, 36),
#  datetime.datetime(2008, 10, 8, 0, 36),
#  datetime.datetime(2008, 10, 8, 0, 36),
#  datetime.datetime(2008, 10, 8, 0, 36),
#  datetime.datetime(2008, 10, 8, 0, 36),
#  datetime.datetime(2008, 10, 8, 0, 47),
#  datetime.datetime(2008, 10, 8, 0, 47),
#  datetime.datetime(2008, 10, 8, 1, 0),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 1, 11),
#  datetime.datetime(2008, 10, 8, 2, 43),
#  datetime.datetime(2008, 10, 8, 3, 12),
#  datetime.datetime(2008, 10, 8, 3, 18),
#  datetime.datetime(2008, 10, 8, 4, 3),
#  datetime.datetime(2008, 10, 8, 4, 3),
#  datetime.datetime(2008, 10, 8, 4, 24),
#  datetime.datetime(2008, 10, 8, 4, 37),
#  datetime.datetime(2008, 10, 8, 5, 43),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 45),
#  datetime.datetime(2008, 10, 8, 5, 59),
#  datetime.datetime(2008, 10, 8, 6, 0),
#  datetime.datetime(2008, 10, 8, 7, 17),
#  datetime.datetime(2008, 10, 8, 7, 56),
#  datetime.datetime(2008, 10, 8, 7, 56),
#  datetime.datetime(2008, 10, 8, 7, 56),
#  datetime.datetime(2008, 10, 8, 7, 56),
#  datetime.datetime(2008, 10, 8, 7, 56),
#  datetime.datetime(2008, 10, 8, 7, 56),
#  datetime.datetime(2008, 10, 8, 8, 0),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 8, 10),
#  datetime.datetime(2008, 10, 8, 9, 56),
#  datetime.datetime(2008, 10, 8, 9, 56),
#  datetime.datetime(2008, 10, 8, 11, 14),
#  datetime.datetime(2008, 10, 8, 11, 14),
#  datetime.datetime(2008, 10, 8, 11, 14),
#  datetime.datetime(2008, 10, 8, 11, 14),
#  datetime.datetime(2008, 10, 8, 11, 14),
#  datetime.datetime(2008, 10, 8, 12, 1),
#  datetime.datetime(2008, 10, 8, 12, 4),
#  datetime.datetime(2008, 10, 8, 12, 4),
#  datetime.datetime(2008, 10, 8, 12, 10),
#  datetime.datetime(2008, 10, 8, 12, 10),
#  datetime.datetime(2008, 10, 8, 12, 15),
#  datetime.datetime(2008, 10, 8, 12, 15),
#  datetime.datetime(2008, 10, 8, 12, 15),
#  datetime.datetime(2008, 10, 8, 12, 30),
#  datetime.datetime(2008, 10, 8, 14, 0),
#  datetime.datetime(2008, 10, 8, 14, 48),
#  datetime.datetime(2008, 10, 8, 14, 48),
#  datetime.datetime(2008, 10, 8, 15, 15),
#  datetime.datetime(2008, 10, 8, 15, 31),
#  datetime.datetime(2008, 10, 8, 15, 31),
#  datetime.datetime(2008, 10, 8, 15, 31),
#  datetime.datetime(2008, 10, 8, 15, 31),
#  datetime.datetime(2008, 10, 8, 15, 31),
#  datetime.datetime(2008, 10, 8, 15, 41),
#  datetime.datetime(2008, 10, 8, 16, 27),
#  datetime.datetime(2008, 10, 8, 17, 0),
#  datetime.datetime(2008, 10, 8, 17, 42),
#  datetime.datetime(2008, 10, 8, 18, 0),
#  datetime.datetime(2008, 10, 8, 18, 0),
#  datetime.datetime(2008, 10, 8, 18, 0),
#  datetime.datetime(2008, 10, 8, 18, 0),
#  datetime.datetime(2008, 10, 8, 18, 0),
#  datetime.datetime(2008, 10, 8, 18, 0),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 18, 45),
#  datetime.datetime(2008, 10, 8, 19, 0),
#  datetime.datetime(2008, 10, 8, 19, 25),
#  datetime.datetime(2008, 10, 8, 19, 29),
#  datetime.datetime(2008, 10, 8, 21, 0),
#  datetime.datetime(2008, 10, 8, 21, 33),
#  datetime.datetime(2008, 10, 8, 22, 0),
#  datetime.datetime(2008, 10, 8, 23, 12),
#  datetime.datetime(2008, 10, 8, 23, 12),
#  datetime.datetime(2008, 10, 8, 23, 12),
#  datetime.datetime(2008, 10, 8, 23, 12),
#  datetime.datetime(2008, 10, 8, 23, 12),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 20),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 8, 23, 59),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 3, 44),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 5, 5),
#  datetime.datetime(2008, 10, 9, 6, 0),
#  datetime.datetime(2008, 10, 9, 6, 44),
#  datetime.datetime(2008, 10, 9, 6, 49),
#  datetime.datetime(2008, 10, 9, 6, 55),
#  datetime.datetime(2008, 10, 9, 7, 1),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 53),
#  datetime.datetime(2008, 10, 9, 7, 55),
#  datetime.datetime(2008, 10, 9, 8, 0),
#  datetime.datetime(2008, 10, 9, 9, 17),
#  datetime.datetime(2008, 10, 9, 10, 14),
#  datetime.datetime(2008, 10, 9, 10, 15),
#  datetime.datetime(2008, 10, 9, 10, 16),
#  datetime.datetime(2008, 10, 9, 10, 16),
#  datetime.datetime(2008, 10, 9, 10, 16),
#  datetime.datetime(2008, 10, 9, 10, 17),
#  datetime.datetime(2008, 10, 9, 11, 5),
#  datetime.datetime(2008, 10, 9, 11, 14),
#  datetime.datetime(2008, 10, 9, 11, 58),
#  datetime.datetime(2008, 10, 9, 11, 58),
#  datetime.datetime(2008, 10, 9, 11, 58),
#  datetime.datetime(2008, 10, 9, 11, 58),
#  datetime.datetime(2008, 10, 9, 11, 58),
#  datetime.datetime(2008, 10, 9, 11, 58),
#  datetime.datetime(2008, 10, 9, 12, 45),
#  datetime.datetime(2008, 10, 9, 13, 0),
#  datetime.datetime(2008, 10, 9, 14, 0),
#  datetime.datetime(2008, 10, 9, 14, 0),
#  datetime.datetime(2008, 10, 9, 14, 0),
#  datetime.datetime(2008, 10, 9, 14, 0),
#  datetime.datetime(2008, 10, 9, 14, 0),
#  datetime.datetime(2008, 10, 9, 14, 34),
#  datetime.datetime(2008, 10, 9, 15, 49),
#  datetime.datetime(2008, 10, 9, 15, 49),
#  datetime.datetime(2008, 10, 9, 15, 49),
#  datetime.datetime(2008, 10, 9, 15, 49),
#  datetime.datetime(2008, 10, 9, 15, 49),
#  datetime.datetime(2008, 10, 9, 16, 26),
#  datetime.datetime(2008, 10, 9, 16, 44),
#  datetime.datetime(2008, 10, 9, 16, 45),
#  datetime.datetime(2008, 10, 9, 17, 48),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 19, 30),
#  datetime.datetime(2008, 10, 9, 20, 0),
#  datetime.datetime(2008, 10, 9, 21, 10),
#  datetime.datetime(2008, 10, 9, 22, 0),
#  datetime.datetime(2008, 10, 9, 22, 0),
#  datetime.datetime(2008, 10, 9, 22, 0),
#  datetime.datetime(2008, 10, 9, 23, 48),
#  datetime.datetime(2008, 10, 9, 23, 48),
#  datetime.datetime(2008, 10, 9, 23, 48),
#  datetime.datetime(2008, 10, 9, 23, 48),
#  datetime.datetime(2008, 10, 9, 23, 48),
#  datetime.datetime(2008, 10, 9, 23, 48),
#  datetime.datetime(2008, 10, 9, 23, 59),
#  datetime.datetime(2008, 10, 10, 5, 0),
#  datetime.datetime(2008, 10, 10, 5, 4),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 5),
#  datetime.datetime(2008, 10, 10, 6, 23),
#  datetime.datetime(2008, 10, 10, 6, 30),
#  datetime.datetime(2008, 10, 10, 7, 16),
#  datetime.datetime(2008, 10, 10, 7, 30),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 7, 31),
#  datetime.datetime(2008, 10, 10, 9, 30),
#  datetime.datetime(2008, 10, 10, 10, 58),
#  datetime.datetime(2008, 10, 10, 11, 0),
#  datetime.datetime(2008, 10, 10, 11, 32),
#  datetime.datetime(2008, 10, 10, 11, 32),
#  datetime.datetime(2008, 10, 10, 11, 32),
#  datetime.datetime(2008, 10, 10, 11, 32),
#  datetime.datetime(2008, 10, 10, 11, 32),
#  datetime.datetime(2008, 10, 10, 11, 32),
#  datetime.datetime(2008, 10, 10, 12, 13),
#  datetime.datetime(2008, 10, 10, 12, 51),
#  datetime.datetime(2008, 10, 10, 12, 53),
#  datetime.datetime(2008, 10, 10, 13, 0),
#  datetime.datetime(2008, 10, 10, 13, 0),
#  datetime.datetime(2008, 10, 10, 13, 0),
#  datetime.datetime(2008, 10, 10, 13, 1),
#  datetime.datetime(2008, 10, 10, 14, 0),
#  datetime.datetime(2008, 10, 10, 14, 44),
#  datetime.datetime(2008, 10, 10, 15, 38),
#  datetime.datetime(2008, 10, 10, 15, 38),
#  datetime.datetime(2008, 10, 10, 15, 38),
#  datetime.datetime(2008, 10, 10, 15, 38),
#  datetime.datetime(2008, 10, 10, 15, 38),
#  datetime.datetime(2008, 10, 10, 16, 29),
#  datetime.datetime(2008, 10, 10, 16, 55),
#  datetime.datetime(2008, 10, 10, 17, 14),
#  datetime.datetime(2008, 10, 10, 18, 20),
#  datetime.datetime(2008, 10, 10, 21, 57),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 0),
#  datetime.datetime(2008, 10, 10, 22, 15),
#  datetime.datetime(2008, 10, 10, 22, 15),
#  datetime.datetime(2008, 10, 10, 22, 20),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 0, 16),
#  datetime.datetime(2008, 10, 11, 1, 4),
#  datetime.datetime(2008, 10, 11, 1, 45),
#  datetime.datetime(2008, 10, 11, 5, 0),
#  datetime.datetime(2008, 10, 11, 6, 27),
#  datetime.datetime(2008, 10, 11, 6, 32),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 40),
#  datetime.datetime(2008, 10, 11, 6, 55),
#  datetime.datetime(2008, 10, 11, 6, 56),
#  datetime.datetime(2008, 10, 11, 7, 40),
#  datetime.datetime(2008, 10, 11, 7, 40),
#  datetime.datetime(2008, 10, 11, 7, 40),
#  datetime.datetime(2008, 10, 11, 7, 40),
#  datetime.datetime(2008, 10, 11, 7, 40),
#  datetime.datetime(2008, 10, 11, 7, 40),
#  datetime.datetime(2008, 10, 11, 8, 26),
#  datetime.datetime(2008, 10, 11, 8, 39),
#  datetime.datetime(2008, 10, 11, 9, 15),
#  datetime.datetime(2008, 10, 11, 11, 11),
#  datetime.datetime(2008, 10, 11, 12, 12),
#  datetime.datetime(2008, 10, 11, 13, 4),
#  datetime.datetime(2008, 10, 11, 13, 4),
#  datetime.datetime(2008, 10, 11, 13, 17),
#  datetime.datetime(2008, 10, 11, 14, 0),
#  datetime.datetime(2008, 10, 11, 14, 0),
#  datetime.datetime(2008, 10, 11, 14, 8),
#  datetime.datetime(2008, 10, 11, 14, 52),
#  datetime.datetime(2008, 10, 11, 15, 8),
#  datetime.datetime(2008, 10, 11, 15, 26),
#  datetime.datetime(2008, 10, 11, 15, 26),
#  datetime.datetime(2008, 10, 11, 15, 26),
#  datetime.datetime(2008, 10, 11, 15, 26),
#  datetime.datetime(2008, 10, 11, 15, 26),
#  datetime.datetime(2008, 10, 11, 16, 37),
#  datetime.datetime(2008, 10, 11, 16, 39),
#  datetime.datetime(2008, 10, 11, 17, 3),
#  datetime.datetime(2008, 10, 11, 19, 43),
#  datetime.datetime(2008, 10, 11, 19, 43),
#  datetime.datetime(2008, 10, 11, 21, 5),
#  datetime.datetime(2008, 10, 11, 21, 57),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 22, 0),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 26),
#  datetime.datetime(2008, 10, 11, 23, 59),
#  datetime.datetime(2008, 10, 12, 6, 0),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 20),
#  datetime.datetime(2008, 10, 12, 6, 40),
#  datetime.datetime(2008, 10, 12, 6, 42),
#  datetime.datetime(2008, 10, 12, 7, 30),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 32),
#  datetime.datetime(2008, 10, 12, 7, 49),
#  datetime.datetime(2008, 10, 12, 7, 56),
#  datetime.datetime(2008, 10, 12, 8, 22),
#  datetime.datetime(2008, 10, 12, 8, 29),
#  datetime.datetime(2008, 10, 12, 11, 0),
#  datetime.datetime(2008, 10, 12, 11, 17),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 11, 36),
#  datetime.datetime(2008, 10, 12, 13, 0),
#  datetime.datetime(2008, 10, 12, 13, 0),
#  datetime.datetime(2008, 10, 12, 13, 17),
#  datetime.datetime(2008, 10, 12, 14, 0),
#  datetime.datetime(2008, 10, 12, 15, 10),
#  datetime.datetime(2008, 10, 12, 15, 10),
#  datetime.datetime(2008, 10, 12, 15, 10),
#  datetime.datetime(2008, 10, 12, 15, 10),
#  datetime.datetime(2008, 10, 12, 15, 10),
#  datetime.datetime(2008, 10, 12, 15, 10),
#  datetime.datetime(2008, 10, 12, 15, 35),
#  datetime.datetime(2008, 10, 12, 16, 39),
#  datetime.datetime(2008, 10, 12, 16, 51),
#  datetime.datetime(2008, 10, 12, 20, 0),
#  datetime.datetime(2008, 10, 12, 21, 41),
#  datetime.datetime(2008, 10, 12, 21, 58),
#  datetime.datetime(2008, 10, 12, 22, 0),
#  datetime.datetime(2008, 10, 12, 22, 0),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 9),
#  datetime.datetime(2008, 10, 13, 0, 14),
#  datetime.datetime(2008, 10, 13, 0, 45),
#  datetime.datetime(2008, 10, 13, 1, 34),
#  datetime.datetime(2008, 10, 13, 6, 0),
#  datetime.datetime(2008, 10, 13, 6, 10),
#  datetime.datetime(2008, 10, 13, 6, 15),
#  datetime.datetime(2008, 10, 13, 6, 45),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 6, 56),
#  datetime.datetime(2008, 10, 13, 7, 47),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 49),
#  datetime.datetime(2008, 10, 13, 7, 59),
#  datetime.datetime(2008, 10, 13, 8, 23),
#  datetime.datetime(2008, 10, 13, 8, 23),
#  datetime.datetime(2008, 10, 13, 9, 49),
#  datetime.datetime(2008, 10, 13, 10, 0),
#  datetime.datetime(2008, 10, 13, 10, 29),
#  datetime.datetime(2008, 10, 13, 10, 31),
#  datetime.datetime(2008, 10, 13, 11, 4),
#  datetime.datetime(2008, 10, 13, 11, 25),
#  datetime.datetime(2008, 10, 13, 11, 31),
#  datetime.datetime(2008, 10, 13, 11, 31),
#  datetime.datetime(2008, 10, 13, 11, 31),
#  datetime.datetime(2008, 10, 13, 11, 31),
#  datetime.datetime(2008, 10, 13, 11, 31),
#  datetime.datetime(2008, 10, 13, 12, 4),
#  datetime.datetime(2008, 10, 13, 12, 30),
#  datetime.datetime(2008, 10, 13, 14, 0),
#  datetime.datetime(2008, 10, 13, 14, 0),
#  datetime.datetime(2008, 10, 13, 14, 35),
#  datetime.datetime(2008, 10, 13, 14, 45),
#  datetime.datetime(2008, 10, 13, 15, 15),
#  datetime.datetime(2008, 10, 13, 15, 15),
#  datetime.datetime(2008, 10, 13, 15, 15),
#  datetime.datetime(2008, 10, 13, 15, 15),
#  datetime.datetime(2008, 10, 13, 15, 15),
#  datetime.datetime(2008, 10, 13, 15, 15),
#  datetime.datetime(2008, 10, 13, 16, 3),
#  datetime.datetime(2008, 10, 13, 16, 6),
#  datetime.datetime(2008, 10, 13, 16, 10),
#  datetime.datetime(2008, 10, 13, 16, 50),
#  datetime.datetime(2008, 10, 13, 19, 0),
#  datetime.datetime(2008, 10, 13, 19, 30),
#  datetime.datetime(2008, 10, 13, 20, 14),
#  datetime.datetime(2008, 10, 13, 20, 37),
#  datetime.datetime(2008, 10, 13, 21, 20),
#  datetime.datetime(2008, 10, 13, 21, 37),
#  datetime.datetime(2008, 10, 13, 21, 41),
#  datetime.datetime(2008, 10, 13, 21, 44),
#  datetime.datetime(2008, 10, 13, 22, 0),
#  datetime.datetime(2008, 10, 13, 22, 0),
#  datetime.datetime(2008, 10, 13, 22, 47),
#  datetime.datetime(2008, 10, 13, 22, 59),
#  datetime.datetime(2008, 10, 13, 23, 0),
#  datetime.datetime(2008, 10, 13, 23, 0),
#  datetime.datetime(2008, 10, 13, 23, 2),
#  datetime.datetime(2008, 10, 13, 23, 25),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 13, 23, 30),
#  datetime.datetime(2008, 10, 14, 0, 30),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 35),
#  datetime.datetime(2008, 10, 14, 0, 36),
#  datetime.datetime(2008, 10, 14, 1, 2),
#  datetime.datetime(2008, 10, 14, 1, 26),
#  datetime.datetime(2008, 10, 14, 1, 33),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 1, 39),
#  datetime.datetime(2008, 10, 14, 2, 34),
#  datetime.datetime(2008, 10, 14, 2, 40),
#  datetime.datetime(2008, 10, 14, 3, 47),
#  datetime.datetime(2008, 10, 14, 3, 51),
#  datetime.datetime(2008, 10, 14, 6, 6),
#  datetime.datetime(2008, 10, 14, 6, 8),
#  datetime.datetime(2008, 10, 14, 6, 11),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 6, 25),
#  datetime.datetime(2008, 10, 14, 7, 32),
#  datetime.datetime(2008, 10, 14, 7, 32),
#  datetime.datetime(2008, 10, 14, 7, 32),
#  datetime.datetime(2008, 10, 14, 7, 32),
#  datetime.datetime(2008, 10, 14, 7, 32),
#  datetime.datetime(2008, 10, 14, 9, 0),
#  datetime.datetime(2008, 10, 14, 9, 0),
#  datetime.datetime(2008, 10, 14, 9, 8),
#  datetime.datetime(2008, 10, 14, 9, 8),
#  datetime.datetime(2008, 10, 14, 9, 22),
#  datetime.datetime(2008, 10, 14, 9, 45),
#  datetime.datetime(2008, 10, 14, 11, 9),
#  datetime.datetime(2008, 10, 14, 14, 0),
#  datetime.datetime(2008, 10, 14, 14, 18),
#  datetime.datetime(2008, 10, 14, 15, 2),
#  datetime.datetime(2008, 10, 14, 15, 27),
#  datetime.datetime(2008, 10, 14, 15, 28),
#  datetime.datetime(2008, 10, 14, 15, 35),
#  datetime.datetime(2008, 10, 14, 15, 35),
#  datetime.datetime(2008, 10, 14, 15, 35),
#  datetime.datetime(2008, 10, 14, 15, 35),
#  datetime.datetime(2008, 10, 14, 15, 35),
#  datetime.datetime(2008, 10, 14, 15, 35),
#  datetime.datetime(2008, 10, 14, 15, 37),
#  datetime.datetime(2008, 10, 14, 15, 40),
#  datetime.datetime(2008, 10, 14, 15, 41),
#  datetime.datetime(2008, 10, 14, 15, 59),
#  datetime.datetime(2008, 10, 14, 16, 42),
#  datetime.datetime(2008, 10, 14, 17, 10),
#  datetime.datetime(2008, 10, 14, 17, 10),
#  datetime.datetime(2008, 10, 14, 17, 10),
#  datetime.datetime(2008, 10, 14, 17, 10),
#  datetime.datetime(2008, 10, 14, 17, 50),
#  datetime.datetime(2008, 10, 14, 21, 23),
#  datetime.datetime(2008, 10, 14, 21, 53),
#  datetime.datetime(2008, 10, 14, 22, 0),
#  datetime.datetime(2008, 10, 14, 22, 0),
#  datetime.datetime(2008, 10, 14, 23, 46),
#  datetime.datetime(2008, 10, 14, 23, 59),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 0, 1),
#  datetime.datetime(2008, 10, 15, 2, 28),
#  datetime.datetime(2008, 10, 15, 3, 0),
#  datetime.datetime(2008, 10, 15, 4, 3),
#  datetime.datetime(2008, 10, 15, 6, 0),
#  datetime.datetime(2008, 10, 15, 6, 0),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 6, 5),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 28),
#  datetime.datetime(2008, 10, 15, 8, 33),
#  datetime.datetime(2008, 10, 15, 9, 0),
#  datetime.datetime(2008, 10, 15, 9, 0),
#  datetime.datetime(2008, 10, 15, 9, 26),
#  datetime.datetime(2008, 10, 15, 9, 30),
#  datetime.datetime(2008, 10, 15, 10, 30),
#  datetime.datetime(2008, 10, 15, 10, 38),
#  datetime.datetime(2008, 10, 15, 10, 50),
#  datetime.datetime(2008, 10, 15, 11, 7),
#  datetime.datetime(2008, 10, 15, 23, 59),
#  datetime.datetime(2008, 11, 3, 14, 34),
#  datetime.datetime(2009, 4, 25, 16, 29)]

# %%
df_labels = pd.read_csv('EHRSHOT_ASSETS/benchmark/lab_anemia/labeled_patients.csv')
df_labels
# Out:
#         patient_id      prediction_time  value   label_type
# 0        115973769  2011-10-01 11:19:00      0  categorical
# 1        115973769  2011-10-05 14:24:00      0  categorical
# 2        115973769  2011-10-06 02:59:00      1  categorical
# 3        115973769  2011-10-08 04:49:00      0  categorical
# 4        115973769  2012-08-24 14:44:00      0  categorical
# ...            ...                  ...    ...          ...
# 184875   115967121  2023-02-10 09:23:00      2  categorical
# 184876   115967121  2023-02-12 08:44:00      2  categorical
# 184877   115967121  2023-02-16 10:45:00      2  categorical
# 184878   115967121  2023-02-23 09:17:00      2  categorical
# 184879   115967121  2023-03-02 09:49:00      2  categorical
#
# [184880 rows x 4 columns]

# %%
for i in range(df_labels.shape[0]):
    current_row = df_labels.iloc[i]
    patient_id = current_row['patient_id']
    label = current_row['value']
    time = current_row['prediction_time']
    print(patient_id, label, time)
    break
# Out:
# 115973769 0 2011-10-01 11:19:00

# %%
# extract the unique patient ids, 
patient_id_list = df_labels['patient_id'].unique()
for patient_id in patient_id_list:
    
    df_current_patient = df_labels[df_labels['patient_id'] == patient_id]
    prediction_time_list = df_current_patient['prediction_time'].values
    value_list = df_current_patient['value'].values
    prediction_time_list = [convert_datetime_string_to_timestamp(time) for time in prediction_time_list]

# %%
df_labels
# Out:
#         patient_id      prediction_time  value   label_type
# 0        115973769  2011-10-01 11:19:00      0  categorical
# 1        115973769  2011-10-05 14:24:00      0  categorical
# 2        115973769  2011-10-06 02:59:00      1  categorical
# 3        115973769  2011-10-08 04:49:00      0  categorical
# 4        115973769  2012-08-24 14:44:00      0  categorical
# ...            ...                  ...    ...          ...
# 184875   115967121  2023-02-10 09:23:00      2  categorical
# 184876   115967121  2023-02-12 08:44:00      2  categorical
# 184877   115967121  2023-02-16 10:45:00      2  categorical
# 184878   115967121  2023-02-23 09:17:00      2  categorical
# 184879   115967121  2023-03-02 09:49:00      2  categorical
#
# [184880 rows x 4 columns]

# %%
# for event in patient_events:
#     start_time = event.start
#     medical_code = event.code
#     if start_time in prediction_time_list:
patient_events = database[patient_id].events
patient_time_list = [event.start for event in patient_events]
patient_code_list = [event.code for event in patient_events]

# %%
prediction_time = prediction_time_list[1]
current_prediction_end_time = bisect_right(patient_time_list, prediction_time)
current_prediction_start_time = bisect_left(patient_time_list, prediction_time)

# %%
current_prediction_start_time, current_prediction_end_time
# Out:
# (2605, 2612)

# %%
def find_max_indices(patient_time_list, prediction_time_list):
    indices = []
    for prediction_time in prediction_time_list:
        index = bisect_right(patient_time_list, prediction_time) - 1
        indices.append(index if index >= 0 else None)  # Return None if prediction_time is before the first patient_time
    return indices

# %%
print(patient_time_list[current_prediction_start_time:current_prediction_end_time])
patient_code_list[current_prediction_start_time:current_prediction_end_time]
# Out:
# [datetime.datetime(2023, 1, 16, 11, 26), datetime.datetime(2023, 1, 16, 11, 26), datetime.datetime(2023, 1, 16, 11, 26), datetime.datetime(2023, 1, 16, 11, 26), datetime.datetime(2023, 1, 16, 11, 26), datetime.datetime(2023, 1, 16, 11, 26), datetime.datetime(2023, 1, 16, 11, 26)]
# ['LOINC/8480-6',
#  'LOINC/3151-8',
#  'LOINC/20112-9',
#  'LOINC/8462-4',
#  'LOINC/9279-1',
#  'LOINC/8867-4',
#  'LOINC/8478-0']

# %%
# import argparse
# import os
# import json
# from typing import List
# from loguru import logger
# from ehrshot.utils import LABELING_FUNCTION_2_PAPER_NAME
# import pandas as pd

# from femr.datasets import PatientDatabase
# from femr.labelers.core import LabeledPatients, Label
# from femr.labelers.benchmarks import (
#     Guo_LongLOSLabeler,
#     Guo_30DayReadmissionLabeler,
#     Guo_ICUAdmissionLabeler,
#     PancreaticCancerCodeLabeler,
#     CeliacDiseaseCodeLabeler,
#     LupusCodeLabeler,
#     AcuteMyocardialInfarctionCodeLabeler,
#     EssentialHypertensionCodeLabeler,
#     HyperlipidemiaCodeLabeler,
#     HyponatremiaInstantLabValueLabeler,
#     ThrombocytopeniaInstantLabValueLabeler,
#     HyperkalemiaInstantLabValueLabeler,
#     HypoglycemiaInstantLabValueLabeler,
#     AnemiaInstantLabValueLabeler,
# )
# from femr.labelers.omop import (
#     ChexpertLabeler,
# )

# database = PatientDatabase("EHRSHOT_ASSETS/femr/extract")
# ontology = database.get_ontology()
# labeler = AnemiaInstantLabValueLabeler(ontology)

# labeled_patients = labeler.apply(
#         path_to_patient_database="EHRSHOT_ASSETS/femr/extract",
#         num_threads=20,
#     )

# for patient, labels in labeled_patients.items():
#     new_labels: List[Label] = [ Label(time=l.time.replace(second=0, microsecond=0), value=l.value) for l in labels ]
#     # labeled_patients[patient] = new_labels
#     # if new_labels > 1:
#     #         print(patient, new_labels)
#     for e in new_labels:
#         print(patient, e.time, e.value)
