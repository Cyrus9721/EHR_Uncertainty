# %%
from langchain_openai import AzureChatOpenAI
from langchain.prompts import ChatPromptTemplate
import os

import truststore
truststore.inject_into_ssl()
import numpy as np
import pandas as pd
from tqdm import tqdm
import time
import seaborn as sns
import numpy as np
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
os.environ["APP_CLIENT_ID"] = "zizhang-chen-research-app"
os.environ["APP_CLIENT_SECRET"] = "cQPcueFP7tDrimbf8NW2GAHcHeQa"
from llm_idam_token_generator.idam_token_generator import get_idam_token
from langchain_community.callbacks import get_openai_callback
from langchain_openai import OpenAI
import tiktoken
import time

# %%
end_point_list = [
    'https://lmaas-beta.ai.gehealthcare.com',
    "https://openai-llm-frontdoor-hma7evbthrd4cugn.a01.azurefd.net"
]

model_list = ["gpt-35-turbo-16k", "gpt-4-32k-beta", "gpt-4o"]

# APIM_KEY = "8b96051ed6b84e4dad762fdc9f8c809e"

OPENAI_ENDPOINT = end_point_list[0]
OPENAI_DEPLOYMENT_MODEL = model_list[0]
OPENAI_AZURE_API_VERSION = "2023-12-01-preview"
# OPENAI_AZURE_API_VERSION = '2024-02-01'
OPENAI_TYPE = "azure"

# %%
# help(AzureChatOpenAI)

llm = AzureChatOpenAI(
    api_key="xxx",  # This is not playing any role, but required as per OpenAI sdk. So any random could be passed.
    azure_endpoint=OPENAI_ENDPOINT,
    deployment_name=OPENAI_DEPLOYMENT_MODEL,
    openai_api_version=OPENAI_AZURE_API_VERSION,
    n = 2,
    default_headers={
        'Authorization': f'Bearer {get_idam_token()}',
        'Content-Type': 'application/json'
    }
)
# Out:
# PID:19143 INFO llm_idam_token_generator.idam_token_generator - Client ID: zizhang-chen-research-app - Generating new token.
# PID:19143 INFO llm_idam_token_generator.idam_token_generator - Client ID: zizhang-chen-research-app - All required environment variables are present.
# /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# PID:19143 INFO llm_idam_token_generator.idam_token_generator - Client ID: zizhang-chen-research-app - IDAM Access Token is generated
# /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# PID:19143 INFO llm_idam_token_generator.idam_token_generator - Client ID: zizhang-chen-research-app - IDAM Exchange Access Token is generated

# %%
def generate_prompt_task(path):
    with open(path) as f:
        prompt = f.readlines()
    return prompt

def split_string_into_two_parts(text):
    lines = text.split('\n')
    first_part = lines[:2]
    second_part = lines[2:]

    first_part_string = '\n'.join(first_part)
    second_part_string = '\n'.join(second_part)
    
    return first_part_string, second_part_string


def combin_prompt_no_cot(general_prompt, person_info, medical_event):
    template_by_task = '**Task:**\n' + general_prompt + '\n'

    person_info = person_info.replace('at the prediction time', 'at the discharge time')
    template_info = '**Patient age and demographic information:**\n' + person_info + '\n'

    template_events = '**Medical Events:**\n' + medical_event + '\n'
    
    template_events_answer_style = "**Answer requirement:**\nPlease only answer with 'Yes' or 'No'"

    return template_by_task + '\n' + '{events}' , template_info + '\n' + template_events + '\n' + template_events_answer_style

def calculate_row_entropy(df):
    def entropy(row):
        counts = row.value_counts(normalize=True)
        return -np.sum(counts * np.log2(counts + np.finfo(float).eps)) 

    return df.apply(entropy, axis=1)

def num_tokens_from_string(string, encoding_model = 'gpt-3.5-turbo') -> int:
    encoding = tiktoken.encoding_for_model(encoding_model)
    num_tokens = len(encoding.encode(string))
    return num_tokens

def generate_prompt_task(new_diagnose, new_diagnose_prediction):
    new_diagnose_single_word = new_diagnose.split('_')[1]
    task = f"You are an experienced doctor. Based on the provided patient age, demographic information and medical events, use your medical knowledge and reasoning to:\n{new_diagnose_prediction}\nYou are given the medical events up to the patient's discharges. Please respond 'Yes' if it is plausible and 'No' otherwise."
    return task

# %%
df = pd.read_csv('data/new_diagnose_patient_description.csv')
description_list = df['description'].values
# new_diagnose_list = [i.split('value_')[1] for i in df.columns[2:8]]
# new_diagnose_prediction = [
#     "Predict whether the patient will have first diagnosis of essential hypertension within the next year after discharge from hospital.",
#     "Predict whether the patient will have first diagnosis of hyperlipidemia within the next year after discharge from hospital.",
#     "Predict whether the patient will have first diagnosis of pancreatic cancer within the next year after discharge from hospital.",
#     "Predict whether the patient will have first diagnosis of celiac disease within the next year after discharge from hospital.",
#     "Predict whether the patient will have first diagnosis of lupus within the next year after discharge from hospital.",
#     "Predict whether the patient will have first diagnosis of an acute myocardial infarction within the next year after discharge from hospital."
# ]
new_diagnose_list = [
    "value_new_hypertension", "value_new_hyperlipidemia", "value_new_acutemi"
]

new_diagnose_prediction = [
        "Predict whether the patient will have first diagnosis of: 'Hypertension', within the next year after discharge from hospital.",
        "Predict whether the patient will have first diagnosis of: 'Hyperlipidemia', within the next year after discharge from hospital.",
        "Predict whether the patient will have first diagnosis of disease: 'Acute Myocardial Infarction', within the next year after discharge from hospital."
    ]

# %%
# for idx in range(len(new_diagnose_list)):
for idx in range(0, len(new_diagnose_list)):
    # for idx in [4]:
    out_csv_names = new_diagnose_list[idx] + '.csv'
    general_prompt = generate_prompt_task(
        new_diagnose=new_diagnose_list[idx],
        new_diagnose_prediction=new_diagnose_prediction[idx])
    # gt_list = df['value_' + new_diagnose_list[idx]].values
    gt_list = df[new_diagnose_list[idx]].values

    with get_openai_callback() as cb:

        answer_list_all = []

        for i in tqdm(range(len(df))):
            # for i in tqdm(range(1)):
            answer_list_5 = []
            for _ in range(5):
                # for _ in range(1):
                current_description = description_list[i]
                person_info, medical_events = split_string_into_two_parts(
                    current_description)
                c, e = combin_prompt_no_cot(general_prompt, person_info,
                                            medical_events)

                prompt = ChatPromptTemplate.from_template(c)
                chain = prompt | llm
                result = chain.invoke({'events': e})
                answer_list_5.append(result.content)
            answer_list_all.append(answer_list_5)

        df_pred = pd.DataFrame(answer_list_all)
        df_pred.columns = ['pred_1', 'pred_2', 'pred_3', 'pred_4', 'pred_5']
        df_pred['gt'] = list(gt_list)
        # df_pred.to_csv(os.path.join('results/gpt35/baseline_new_diagnose/', out_csv_names))
        # df_pred.to_csv(os.path.join('results/gpt4/baseline_new_diagnose/', out_csv_names))
    # df_pred.to_csv(os.path.join('results/gpt4/baseline_new_diagnose_v1/', out_csv_names))
    df_pred.to_csv(os.path.join('results/gpt35/baseline_new_diagnose_v2/', out_csv_names))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   1%|          | 1/100 [00:02<03:39,  2.22s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   2%|▏         | 2/100 [00:04<03:25,  2.10s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   3%|▎         | 3/100 [00:06<03:25,  2.12s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   4%|▍         | 4/100 [00:09<03:44,  2.34s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   5%|▌         | 5/100 [00:10<03:22,  2.13s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   6%|▌         | 6/100 [00:13<03:21,  2.15s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   7%|▋         | 7/100 [00:15<03:37,  2.34s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   8%|▊         | 8/100 [00:18<03:40,  2.39s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#   9%|▉         | 9/100 [00:20<03:39,  2.41s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  10%|█         | 10/100 [00:22<03:26,  2.30s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  11%|█         | 11/100 [00:24<03:22,  2.27s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  12%|█▏        | 12/100 [00:27<03:35,  2.44s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  13%|█▎        | 13/100 [00:29<03:22,  2.33s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  14%|█▍        | 14/100 [00:33<03:53,  2.72s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  15%|█▌        | 15/100 [00:35<03:41,  2.61s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  16%|█▌        | 16/100 [00:38<03:48,  2.72s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  17%|█▋        | 17/100 [00:41<03:43,  2.70s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  18%|█▊        | 18/100 [00:43<03:29,  2.55s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  19%|█▉        | 19/100 [00:46<03:26,  2.55s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  20%|██        | 20/100 [00:48<03:18,  2.48s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  21%|██        | 21/100 [00:50<03:06,  2.36s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  22%|██▏       | 22/100 [00:52<02:58,  2.29s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  23%|██▎       | 23/100 [00:55<03:01,  2.36s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  24%|██▍       | 24/100 [00:57<02:57,  2.33s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  25%|██▌       | 25/100 [00:59<02:58,  2.38s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  26%|██▌       | 26/100 [01:02<02:55,  2.37s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  27%|██▋       | 27/100 [01:04<02:47,  2.30s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  28%|██▊       | 28/100 [01:07<02:53,  2.40s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  29%|██▉       | 29/100 [01:09<02:50,  2.40s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  30%|███       | 30/100 [01:11<02:43,  2.33s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  31%|███       | 31/100 [01:13<02:33,  2.22s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  32%|███▏      | 32/100 [01:15<02:32,  2.24s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  33%|███▎      | 33/100 [01:18<02:33,  2.29s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  34%|███▍      | 34/100 [01:20<02:24,  2.19s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  35%|███▌      | 35/100 [01:22<02:27,  2.27s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  36%|███▌      | 36/100 [01:24<02:21,  2.21s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  37%|███▋      | 37/100 [01:28<02:39,  2.52s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  38%|███▊      | 38/100 [01:30<02:36,  2.52s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  39%|███▉      | 39/100 [01:32<02:30,  2.47s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  40%|████      | 40/100 [01:35<02:33,  2.56s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  41%|████      | 41/100 [01:37<02:24,  2.44s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# ...
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  87%|████████▋ | 87/100 [03:22<00:32,  2.50s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  88%|████████▊ | 88/100 [03:25<00:31,  2.66s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  89%|████████▉ | 89/100 [03:27<00:28,  2.56s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  90%|█████████ | 90/100 [03:30<00:26,  2.62s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  91%|█████████ | 91/100 [03:32<00:22,  2.50s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  92%|█████████▏| 92/100 [03:34<00:19,  2.43s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  93%|█████████▎| 93/100 [03:37<00:17,  2.48s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  94%|█████████▍| 94/100 [03:40<00:15,  2.66s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  95%|█████████▌| 95/100 [03:42<00:12,  2.54s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  96%|█████████▌| 96/100 [03:44<00:09,  2.35s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  97%|█████████▋| 97/100 [03:47<00:07,  2.41s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  98%|█████████▊| 98/100 [03:49<00:04,  2.33s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
#  99%|█████████▉| 99/100 [03:51<00:02,  2.31s/it]PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# PID:19143 INFO httpx - Client ID: zizhang-chen-research-app - HTTP Request: POST https://lmaas-beta.ai.gehealthcare.com/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-12-01-preview "HTTP/1.1 200 OK"
# 100%|██████████| 100/100 [03:53<00:00,  2.33s/it]

# %%
cb
# Out:
# Tokens Used: 2195855
# 	Prompt Tokens: 2194850
# 	Completion Tokens: 1005
# Successful Requests: 500
# Total Cost (USD): $6.588569999999996

# %%
cb
# Out:
# Tokens Used: 2195855
# 	Prompt Tokens: 2194850
# 	Completion Tokens: 1005
# Successful Requests: 500
# Total Cost (USD): $6.588569999999996

# %%
print(e)
# Out:
# **Patient age and demographic information:**
# The patient was 36 years old at the discharge time.
# The patient has the following demographic information: Asian,FEMALE,Not Hispanic or Latino.
#
# **Medical Events:**
# At June 12, 2014:
# 1 events:'oxycodone hydrochloride 5 MG Oral Tablet' recorded
# 1 events:'Acetaminophen 10 MG/ML Injectable Solution' recorded
# 1 events:'1 ML ketorolac tromethamine 15 MG/ML Injection' recorded
# 46 events:'Heart rate' recorded with values: 83.0, 84.0, 89.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 98.0, 99.0, 100.0, 101.0, 103.0, 104.0, 105.0, 106.0, 108.0, 109.0, 117.0.
# 29 events:'Systolic blood pressure' recorded with values: 129.0, 131.0, 132.0, 133.0, 134.0, 136.0, 137.0, 138.0, 141.0, 147.0, 148.0, 115.0, 117.0, 118.0, 119.0, 120.0, 121.0, 122.0, 124.0, 125.0, 127.0.
# 26 events:'Diastolic blood pressure' recorded with values: 64.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 73.0, 75.0, 76.0, 79.0, 81.0, 50.0, 51.0, 83.0, 55.0, 56.0, 59.0.
# 1 events:'Inhaled oxygen flow rate' recorded with values: 4.199999809265137.
# 5 events:'Respiratory rate' recorded with values: 0.0, 16.0, 18.0, 20.0.
# 2 events:'Oxygen/Total gas setting [Volume Fraction] Ventilator' recorded with values: 32.0, 52.0.
# 2 events:'Minute volume setting Ventilator' recorded with values: 0.0, 2.5.
# 2 events:'Minimum alveolar concentration (MAC) for anesthesia.XXX Anesthetic agent.XXX' recorded with values: 0.0, 0.20000000298023224.
# 1 events:'Nitrous oxide [VFr/PPres] Gas delivery system' recorded with values: 3.9000000953674316.
# 9 events:'Oxygen saturation' recorded with values: 98.0, 99.0, 100.0.
# 1 events:'acetaminophen 325 MG Oral Tablet' recorded
# 1 events:'ibuprofen 600 MG Oral Tablet' recorded
# 3 events:'Input/Output' recorded with values: 700.0, 350.0, 175.0.
# 11 events:'Body temperature' recorded with values: 97.9000015258789, 97.30000305175781, 97.69999694824219, 36.599998474121094, 36.5, 36.29999923706055, 98.4000015258789, 36.900001525878906.
# 1 events:'Patient transfer' recorded
# 1 events:'Anesthesiology Postoperative evaluation and management note' recorded
# 2 events:'Procedure note' recorded
# 1 events:'Discharge summary' recorded
# 1 events:'Note' recorded
# 1 events:'CARE_SITE/7929069' recorded
# 1 events:'simethicone 80 MG Chewable Tablet' recorded
# 1 events:'Hematocrit determination' recorded
# 1 events:'methylergonovine maleate 0.2 MG Oral Tablet' recorded
# 1 events:'1 ML methylergonovine maleate 0.2 MG/ML Injection' recorded
# 1 events:'Finding related to pregnancy' recorded
# 1 events:'Other vacuum extraction' recorded
# 1 events:'Other fetal monitoring' recorded
# 1 events:'Anesthesia for cesarean delivery only' recorded
# 1 events:'Fetal non-stress test' recorded
# 1 events:'Surgery Note' recorded
# 1 events:'Tobacco user' recorded
# 1 events:'Single live birth' recorded
# 1 events:'Snuff consumption' recorded with values: N.
# 1 events:'Chewed tobacco consumption' recorded with values: N.
# 1 events:'Postpartum finding' recorded
# 1 events:'Cigarette consumption' recorded with values: N.
# 1 events:'Pipe tobacco consumption' recorded with values: N.
# 1 events:'Postpartum care' recorded
# 1 events:'Cigar consumption' recorded with values: N.
# 1 events:'Uterine scar from previous surgery in pregnancy, childbirth and the puerperium - delivered' recorded
# 1 events:'History of clinical finding in subject' recorded
# 1 events:'User of smokeless tobacco' recorded
# 1 events:'Lower uterine segment cesarean section' recorded
# 1 events:'Hospital' recorded
# 1 events:'acetaminophen 325 MG / oxycodone hydrochloride 5 MG Oral Tablet' recorded
# 1 events:'Injection(s), including indwelling catheter placement, continuous infusion or intermittent bolus, of diagnostic or therapeutic substance(s) (eg, anesthetic, antispasmodic, opioid, steroid, other solution), not including neurolytic substances, interlaminar' recorded
# 1 events:'docusate sodium 250 MG Oral Capsule' recorded
# 1 events:'Tobacco smoking status' recorded
# At June 13, 2014:
# 1 events:'oxycodone hydrochloride 5 MG Oral Tablet' recorded
# 5 events:'Systolic blood pressure' recorded with values: 131.0, 127.0, 133.0, 143.0.
# 5 events:'Diastolic blood pressure' recorded with values: 76.0, 81.0, 86.0, 87.0, 89.0.
# 11 events:'Body temperature' recorded with values: 97.9000015258789, 98.19999694824219, 98.0999984741211, 36.599998474121094, 36.79999923706055, 36.70000076293945.
# 2 events:'Respiratory rate' recorded with values: 18.0, 20.0.
# 1 events:'Body temperature measurement site' recorded with values: 1.0.
# 1 events:'acetaminophen 325 MG Oral Tablet' recorded
# 1 events:'Hematocrit [Volume Fraction] of Blood by Automated count' recorded with values: 31.299999237060547.
# 1 events:'Hemoglobin level estimation' recorded with values: 10.800000190734863.
# 7 events:'Note' recorded
# 2 events:'Progress note' recorded
# 1 events:'Anesthesiology Postoperative evaluation and management note' recorded
# 2 events:'Input/Output' recorded with values: 600.0, 200.0.
# 1 events:'diphenhydramine hydrochloride 25 MG Oral Capsule' recorded
# 1 events:'docusate sodium 250 MG Oral Capsule' recorded
# 1 events:'ibuprofen 600 MG Oral Tablet' recorded
# 4 events:'Heart rate' recorded with values: 106.0, 108.0, 109.0, 71.0.
# 1 events:'lanolin Topical Cream' recorded
# 1 events:'Collection of venous blood by venipuncture' recorded
# 1 events:'bisacodyl 10 MG Rectal Suppository' recorded
# 1 events:'aluminum hydroxide 40 MG/ML / magnesium hydroxide 40 MG/ML / simethicone 4 MG/ML Oral Suspension' recorded
# 1 events:'1 ML ketorolac tromethamine 15 MG/ML Injection' recorded
# At June 14, 2014:
# 2 events:'Progress note' recorded
# 1 events:'oxycodone hydrochloride 5 MG Oral Tablet' recorded
# 1 events:'docusate sodium 250 MG Oral Capsule' recorded
# 1 events:'acetaminophen 325 MG Oral Tablet' recorded
# 1 events:'ibuprofen 600 MG Oral Tablet' recorded
# 3 events:'Systolic blood pressure' recorded with values: 132.0, 124.0, 125.0.
# 3 events:'Diastolic blood pressure' recorded with values: 82.0, 83.0, 71.0.
# 6 events:'Body temperature' recorded with values: 97.69999694824219, 98.19999694824219, 97.9000015258789, 36.79999923706055, 36.5, 36.599998474121094.
# 1 events:'Respiratory rate' recorded with values: 18.0.
# 1 events:'Body temperature measurement site' recorded with values: 1.0.
# 3 events:'Heart rate' recorded with values: 97.0, 98.0, 111.0.
# 1 events:'simethicone 80 MG Chewable Tablet' recorded
# 1 events:'Note' recorded
# At June 15, 2014:
# 1 events:'oxycodone hydrochloride 5 MG Oral Tablet' recorded
# 2 events:'Note' recorded
# 2 events:'Progress note' recorded
# 1 events:'acetaminophen 325 MG Oral Tablet' recorded
# 1 events:'ibuprofen 600 MG Oral Tablet' recorded
# 1 events:'simethicone 80 MG Chewable Tablet' recorded
# 2 events:'Systolic blood pressure' recorded with values: 120.0, 131.0.
# 2 events:'Diastolic blood pressure' recorded with values: 81.0, 79.0.
# 4 events:'Body temperature' recorded with values: 97.9000015258789, 36.599998474121094.
# 1 events:'Respiratory rate' recorded with values: 18.0.
# 1 events:'Body temperature measurement site' recorded with values: 1.0.
# 2 events:'Heart rate' recorded with values: 97.0, 100.0.
# 1 events:'docusate sodium 250 MG Oral Capsule' recorded
# 1 events:'lanolin Topical Cream' recorded
# At June 16, 2014:
# 1 events:'simethicone 80 MG Chewable Tablet' recorded
# 1 events:'acetaminophen 325 MG Oral Tablet' recorded
# 1 events:'ibuprofen 600 MG Oral Tablet' recorded
# 1 events:'oxycodone hydrochloride 5 MG Oral Tablet' recorded
# 2 events:'Progress note' recorded
# 2 events:'Systolic blood pressure' recorded with values: 138.0, 125.0.
# 1 events:'Diastolic blood pressure' recorded with values: 88.0.
# 2 events:'Body temperature' recorded with values: 98.0999984741211, 36.70000076293945.
# 1 events:'Body temperature measurement site' recorded with values: 1.0.
# 1 events:'Heart rate' recorded with values: 98.0.
# 1 events:'docusate sodium 250 MG Oral Capsule' recorded
# 1 events:'Note' recorded
# 1 events:'lanolin Topical Cream' recorded
# 1 events:'High head at term - delivered' recorded
# 1 events:'Benign essential hypertension complicating pregnancy, childbirth and the puerperium - delivered' recorded
# 1 events:'Complication of pregnancy, childbirth and/or puerperium' recorded
# 1 events:'Finding related to pregnancy' recorded
# 1 events:'Single live birth' recorded
# 1 events:'Postpartum finding' recorded
# 1 events:'Uterine scar from previous surgery in pregnancy, childbirth and the puerperium - delivered' recorded
# 1 events:'High risk pregnancy' recorded
# 1 events:'Group B Streptococcus carrier' recorded
#
#
# **Answer requirement:**
# Please only answer with 'Yes' or 'No'

# %%
cb
# Out:
# Tokens Used: 2195855
# 	Prompt Tokens: 2194850
# 	Completion Tokens: 1005
# Successful Requests: 500
# Total Cost (USD): $6.588569999999996
