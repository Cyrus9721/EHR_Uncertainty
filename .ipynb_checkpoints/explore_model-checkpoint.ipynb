# %%
from __future__ import annotations

import argparse
import datetime
import logging
import math
import os
import queue
import random
import sys
import threading
from typing import Any, List, Optional, Tuple, TypeVar

import jax
import msgpack
import numpy as np

import femr.datasets
import femr.extension.dataloader
import femr.labelers

T = TypeVar("T")

BatchLoader = femr.extension.dataloader.BatchLoader


def _index_thread(
    index_queue: queue.Queue[Optional[Tuple[int, int]]],
    seed: int,
    num_epochs: int,
    num_batch_threads: int,
    split: str,
    data_path: str,
    batch_info_path: str,
    num_batches: int,
) -> None:
    """Generate indices in random order and add them to the queue."""
    rng = random.Random(seed)
    step = 0
    for _ in range(num_epochs):
        order: List[int] = list(range(num_batches))
        rng.shuffle(order)

        for i in order:
            index_queue.put((i, step))
            step += 1

    for _ in range(num_batch_threads):
        index_queue.put(None)


def _batch_thread(
    index_queue: queue.Queue[Optional[Tuple[int, int]]],
    batch_queue: queue.Queue[Optional[Tuple[Any, int]]],
    data_path: str,
    batch_info_path: str,
    token_dropout: float,
    split: str,
) -> None:
    """Load batches according to the indices in the index thread and add them to the batch queue."""
    thread_loader = BatchLoader(data_path, batch_info_path, token_dropout=token_dropout)
    while True:
        next_item = index_queue.get()
        if next_item is None:
            batch_queue.put(None)
            break

        batch_index, step = next_item

        batch = thread_loader.get_batch(split, batch_index)
        if batch["num_indices"] == 0:
            batch_queue.put((None, step))
        else:
            batch = jax.tree_map(lambda a: jax.device_put(a, device=jax.devices("cpu")[0]), batch)
            batch_queue.put((batch, step))

    batch_queue.put(None)


class Batches:
    def __init__(
        self,
        data_path: str,
        batch_info_path: str,
        token_dropout: float,
        seed: int,
        num_epochs: int,
        num_batch_threads: int,
        num_batches: int,
        split: str = "train",
    ):
        print("Working with seed", seed, file=sys.stderr)
        """Create a multithreaded batch loader for the given batch info."""
        index_queue: queue.Queue[Optional[int]] = queue.Queue(maxsize=300)
        _ = index_queue

        self.batch_queue: queue.Queue[Optional[Any]] = queue.Queue(maxsize=5)

        batch_queue = self.batch_queue
        _ = batch_queue

        local = locals()

        batcher_thread = threading.Thread(
            target=_index_thread,
            kwargs={
                k: local[k]
                for k in (
                    "index_queue",
                    "seed",
                    "num_batch_threads",
                    "num_epochs",
                    "data_path",
                    "batch_info_path",
                    "num_batches",
                    "split",
                )
            },
            name="batch_thread",
            daemon=True,
        )
        batcher_thread.start()

        batcher_threads = [
            threading.Thread(
                target=_batch_thread,
                kwargs={
                    k: local[k]
                    for k in (
                        "index_queue",
                        "batch_queue",
                        "data_path",
                        "batch_info_path",
                        "data_path",
                        "token_dropout",
                        "split",
                    )
                },
                name="batch_thread",
                daemon=True,
            )
            for _ in range(num_batch_threads)
        ]

        for t in batcher_threads:
            t.start()

        self.remaining_threads = num_batch_threads

    def get_next(self) -> Optional[Any]:
        """Get the next batch, or None if we are out of batches."""
        next_item = None

        while next_item is None:
            next_item = self.batch_queue.get()
            if next_item is not None:
                return next_item
            else:
                self.remaining_threads -= 1
                if self.remaining_threads == 0:
                    return None

# %%
# import os
# os.listdir('EHRSHOT_ASSETS/models/clmbr/dictionary')

# %%
dict_path = "EHRSHOT_ASSETS/models/clmbr/dictionary"
is_hierarchical = False
transformer_vocab_size = 1024 * 64
data_path = 'EHRSHOT_ASSETS/femr/extract'
with open(dict_path, "rb") as f:
        dictionary = msgpack.load(f, use_list=False)

        if is_hierarchical:
            dict_len = len(dictionary["ontology_rollup"])
        else:
            dict_len = len(dictionary["regular"])

        assert (
            transformer_vocab_size <= dict_len
        ), f"Transformer vocab size ({transformer_vocab_size}) must be <= len(dictionary) ({dict_len})"

data = femr.datasets.PatientDatabase(data_path)

# %%
data[115967098].events
# Out:
# (Event(start=1943-12-15 00:00:00, code=SNOMED/3950001, value=None, =109886, omop_table=person),
#  Event(start=1943-12-15 23:59:00, code=Race/5, value=None, =63, omop_table=person),
#  Event(start=1943-12-15 23:59:00, code=Gender/F, value=None, =123, omop_table=person),
#  Event(start=1943-12-15 23:59:00, code=Ethnicity/Not Hispanic, value=None, =169495, omop_table=person),
#  Event(start=1997-01-04 23:59:00, code=LOINC/68848-1, value=None, =68985, omop_table=note),
#  Event(start=1998-07-13 23:59:00, code=LOINC/11506-3, value=None, =35301, omop_table=note),
#  Event(start=1998-11-07 11:15:00, code=LOINC/2714-4, value=95.9000015258789, =505718, unit=%, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=LOINC/19218-7, value=14.300000190734863, =589358, unit=mL/dL, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=LOINC/3150-0, value=21.0, =261347, unit=%, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=LOINC/8310-5, value=None, =31853, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=LOINC/8327-9, value=None, =32141, visit_id=28923412.0, omop_table=observation),
#  Event(start=1998-11-07 11:15:00, code=LOINC/2703-7, value=77.5, =340130, unit=mm HG, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=LOINC/48703-3, value=31.0, =275867, unit=%, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=SNOMED/113080007, value=97.5, =391138, unit=%, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=SNOMED/19821003, value=1.399999976158142, =520242, unit=%, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=SNOMED/250564007, value=27.899999618530273, =599002, unit=mEq/L, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=SNOMED/25284008, value=38.599998474121094, =610101, unit=mm HG, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=SNOMED/81065003, value=7.460000038146973, =549958, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1998-11-07 11:15:00, code=SNOMED/88645003, value=26.700000762939453, =599462, unit=mEq/L, visit_id=28923412.0, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/32167-9, value=Clear, =495809, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/25428-4, value=Negative, =498910, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/5794-3, value=Negative, =498036, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/20454-5, value=Negative, =500528, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/30405-5, value=None, =56733, unit=/HPF, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/5802-4, value=Negative, =500079, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/5803-2, value=5.5, =219145, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/5778-6, value=None, =28561, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/2514-8, value=Negative, =497966, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=LOINC/45335-7, value=Few, =230036, omop_table=measurement),
#  Event(start=1999-09-22 03:50:00, code=SNOMED/127800008, value=None, =136531, omop_table=measurement),
#  Event(start=1999-09-22 04:59:00, code=LOINC/36643-5, value=None, =64052, omop_table=procedure_occurrence),
#  Event(start=1999-09-22 13:45:00, code=LOINC/2947-0, value=132.0, =439572, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=LOINC/22735-5, value=33.099998474121094, =607732, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=LOINC/1995-0, value=0.9300000071525574, =574040, unit=mmol/L, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=LOINC/8327-9, value=None, =31573, omop_table=observation),
#  Event(start=1999-09-22 13:45:00, code=LOINC/2703-7, value=421.5, =477661, unit=mm HG, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=LOINC/48703-3, value=26.0, =270955, unit=%, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/113080007, value=99.69999694824219, =562971, unit=%, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/104589004, value=98.0, =396359, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/104846005, value=421.5, =478579, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/167018008, value=None, =137603, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/250564007, value=34.29999923706055, =532447, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/25284008, value=39.599998474121094, =610373, unit=mm HG, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/33747003, value=144.0, =449353, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/312468003, value=3.5999999046325684, =603859, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/81065003, value=7.539999961853027, =551009, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/88645003, value=33.099998474121094, =607136, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/91308007, value=None, =123737, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/441689006, value=8.800000190734863, =555662, unit=g/dL, omop_table=measurement),
#  Event(start=1999-09-22 13:45:00, code=SNOMED/789351000000105, value=9.800000190734863, =559305, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=LOINC/22735-5, value=29.0, =273644, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=LOINC/1995-0, value=0.8399999737739563, =569929, unit=mmol/L, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=LOINC/2703-7, value=524.7000122070312, =544316, unit=mm HG, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=SNOMED/104589004, value=99.0, =401471, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=SNOMED/104846005, value=524.7000122070312, =546158, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=SNOMED/250564007, value=29.899999618530273, =601275, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=SNOMED/25284008, value=29.700000762939453, =600618, unit=mm HG, omop_table=measurement),
#  Event(start=1999-09-22 15:25:00, code=SNOMED/33747003, value=160.0, =453355, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-09
unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/718-7, value=10.300000190734863, =583454, unit=g/dL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/731-0, value=0.5400000214576721, =567526, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/20584-9, value=8.899999618530273, =555210, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/770-8, value=92.0, =371196, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/786-4, value=33.900001525878906, =606313, unit=g/dL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/713-8, value=0.10000000149011612, =615800, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/5905-5, value=1.7999999523162842, =583154, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/785-6, value=29.799999237060547, =602088, unit=pg, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/704-7, value=0.009999999776482582, =620797, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/751-8, value=8.170000076293945, =553715, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/706-2, value=0.10000000149011612, =613008, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/788-0, value=14.800000190734863, =589179, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/789-8, value=3.4700000286102295, =603689, unit=MIL/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/4544-3, value=30.5, =275565, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/787-2, value=87.80000305175781, =555432, unit=fL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/777-3, value=71.0, =324966, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/711-2, value=0.009999999776482582, =622300, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/742-7, value=0.1599999964237213, =563040, unit=K/uL, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=LOINC/736-9, value=6.0, =218866, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 04:05:00, code=CPT4/85027, value=None, =11951, omop_table=measurement),
#  Event(start=1999-09-24 06:19:00, code=LOINC/30746-2, value=None, =56720, omop_table=procedure_occurrence),
#  Event(start=1999-09-24 07:45:00, code=LOINC/22735-5, value=28.899999618530273, =599875, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=LOINC/3150-0, value=40.0, =284315, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=LOINC/8310-5, value=36.400001525878906, =609261, unit=deg C, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=LOINC/2703-7, value=117.0, =428609, unit=mm HG, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=LOINC/48703-3, value=32.0, =277205, unit=%, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/104846005, value=117.0, =430121, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/250564007, value=30.200000762939453, =605669, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/25284008, value=44.099998474121094, =613759, unit=mm HG, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/81065003, value=7.429999828338623, =550979, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/88645003, value=28.899999618530273, =600176, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/441689006, value=10.800000190734863, =584422, unit=g/dL, omop_table=measurement),
#  Event(start=1999-09-24 07:45:00, code=SNOMED/789351000000105, value=3.9000000953674316, =602648, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-09-24 10:40:00, code=LOINC/14979-9, value=43.29999923706055, =541021, unit=sec, omop_table=measurement),
#  Event(start=1999-09-24 10:40:00, code=LOINC/6301-6, value=2.299999952316284, =524427, unit=INR, omop_table=measurement),
#  Event(start=1999-09-24 10:40:00, code=LOINC/5902-2, value=24.899999618530273, =596663, unit=sec, omop_table=measurement),
#  Event(start=1999-09-24 15:46:00, code=LOINC/5811-5, value=1.0140000581741333, =574190, omop_table=measurement),
#  Event(start=1999-09-24 15:46:00, code=LOINC/5799-2, value=Trace, =497338, omop_table=measurement),
#  Event(start=1999-09-24 15:46:00, code=LOINC/11277-1, value=Few, =229546, omop_table=measurement),
omop_table=measurement),
#  Event(start=1999-10-02 05:55:00, code=SNOMED/69480007, value=None, =120908, omop_table=measurement),
#  Event(start=1999-10-02 05:55:00, code=SNOMED/165550008, value=1.0, =204600, unit=%, omop_table=measurement),
#  Event(start=1999-10-02 05:55:00, code=SNOMED/165551007, value=5.0, =220156, unit=%, omop_table=measurement),
#  Event(start=1999-10-02 05:55:00, code=LOINC/69742-5, value=None, =71422, omop_table=measurement),
#  Event(start=1999-10-02 05:55:00, code=CPT4/85027, value=None, =11941, omop_table=measurement),
#  Event(start=1999-10-02 05:55:00, code=CPT4/80053, value=None, =9030, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=LOINC/28570-0, value=None, =54370, omop_table=note),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/113075003, value=2.299999952316284, =524343, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/105011006, value=36.0, =280909, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/14089001, value=3.4700000286102295, =603214, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/25197003, value=134.0, =442389, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/250564007, value=27.0, =272045, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/28317006, value=30.5, =275249, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/271026005, value=10.800000190734863, =586075, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/271240001, value=8.399999618530273, =554417, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/359986008, value=5.300000190734863, =542542, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/59573005, value=4.699999809265137, =539260, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/45896001, value=66.0, =317360, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/61928009, value=395.0, =474224, omop_table=measurement),
#  Event(start=1999-10-02 23:59:00, code=SNOMED/767002, value=27.700000762939453, =601320, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/718-7, value=9.800000190734863, =559289, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2345-7, value=401.0, =476764, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/20584-9, value=19.0, =257956, unit=K/uL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/17861-6, value=7.900000095367432, =551465, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/786-4, value=35.099998474121094, =606989, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/785-6, value=31.299999237060547, =605454, unit=pg, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/3094-0, value=39.0, =282516, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/1920-8, value=50.0, =288442, unit=IU/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2075-0, value=97.0, =386070, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2028-9, value=27.0, =271677, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2160-0, value=2.4000000953674316, =592385, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2951-2, value=132.0, =440940, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/788-0, value=16.200000762939453, =588684, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/789-8, value=3.1500000953674316, =601124, unit=MIL/uL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2885-2, value=5.099999904632568, =541882, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2336-6, value=2.799999952316284, =526381, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/744-3, value=1.0, =197307, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2823-3, value=5.599999904632568, =544004, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/4544-3, value=28.0, =272810, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/787-2, value=89.0, =364654, unit=fL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/1975-2, value=4.199999809265137, =537943, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/1751-7, value=2.299999952316284, =524053, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/777-3, value=246.0, =462218, unit=K/uL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/11253-2, value=7.699999809265137, =550913, unit=ng/mL, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/2324-2, value=945.0, =495183, unit=IU/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/23761-0, value=84.0, =355341, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/6768-6, value=459.0, =483927, unit=IU/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/737-7, value=5.0, =215255, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/33037-3, value=8.0, =225386, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/49229-8, value=1.0, =202236, unit=/100WBC, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=SNOMED/10820006, value=None, =110389, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=SNOMED/25340006, value=6.0, =222197, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=SNOMED/18207002, value=16.0, =249311, unit=ratio, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=SNOMED/69480007, value=None, =120827, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=SNOMED/165550008, value=2.0, =209182, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=SNOMED/165551007, value=2.0, =210159, unit=%, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=LOINC/69742-5, value=None, =71083, omop_table=measurement),
#  Event(start=1999-10-03 06:00:00, code=CPT4/80053, value=None, =10294, omop_table=measurement),
#  Event(start=1999-10-03 12:37:00, code=LOINC/28570-0, value=None, =54484, omop_table=note),
#  Event(start=1999-10-03 23:59:00, code=LOINC/28570-0, value=None, =50739, omop_table=note),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/113075003, value=2.4000000953674316, =593789, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/105011006, value=39.0, =281678, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/14089001, value=3.1500000953674316, =601630, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/25197003, value=132.0, =440828, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/250564007, value=27.0, =271726, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/28317006, value=28.0, =273672, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/271026005, value=9.800000190734863, =557798, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/271240001, value=7.900000095367432, =553204, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/359986008, value=4.199999809265137, =537699, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/59573005, value=5.599999904632568, =545402, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/45896001, value=50.0, =291142, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/61928009, value=246.0, =461631, omop_table=measurement),
#  Event(start=1999-10-03 23:59:00, code=SNOMED/767002, value=19.0, =258263, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/718-7, value=9.100000381469727, =556620, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/2345-7, value=250.0, =462107, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/20584-9, value=19.700000762939453, =591570, unit=K/uL, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/17861-6, value=7.800000190734863, =551616, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/786-4, value=34.29999923706055, =532874, unit=g/dL, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/785-6, value=30.899999618530273, =604525, unit=pg, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/3094-0, value=48.0, =286221, unit=mg/dL, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/1920-8, value=52.0, =291910, unit=IU/L, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/2075-0, value=97.0, =385229, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/2028-9, value=28.0, =272752, unit=mEq/L, omop_table=measurement),
#  Event(start=1999-10-04 06:20:00, code=LOINC/2160-0, value=3.0, =210152, unit=mg/dL, omop_table=measurement),
#  ...)

# %%
data.get_patient(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.get_patient(0)
#
# AttributeError: 'femr.extension.datasets.PatientDatabase' object has no attribute 'get_patient'

# %%
import inspect
from femr.extension.dataloader import create_batches, BatchLoader

# %%
# inspect.getsource(create_batches)
inspect.getsource(BatchLoader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # inspect.getsource(create_batches)
# ----> 2 inspect.getsource(BatchLoader)
#
# File ~/anaconda3/envs/EHRSHOT_ENV/lib/python3.10/inspect.py:1139, in getsource(object)
#    1133 def getsource(object):
#    1134     """Return the text of the source code for an object.
#    1135
#    1136     The argument may be a module, class, method, function, traceback, frame,
#    1137     or code object.  The source code is returned as a single string.  An
#    1138     OSError is raised if the source code cannot be retrieved."""
# -> 1139     lines, lnum = getsourcelines(object)
#    1140     return ''.join(lines)
#
# File ~/anaconda3/envs/EHRSHOT_ENV/lib/python3.10/inspect.py:1121, in getsourcelines(object)
#    1113 """Return a list of source lines and starting line number for an object.
#    1114
#    1115 The argument may be a module, class, method, function, traceback, frame,
#    (...)
#    1118 original source file the first line of code was found.  An OSError is
#    1119 raised if the source code cannot be retrieved."""
#    1120 object = unwrap(object)
# -> 1121 lines, lnum = findsource(object)
#    1123 if istraceback(object):
#    1124     object = object.tb_frame
#
# File ~/anaconda3/envs/EHRSHOT_ENV/lib/python3.10/inspect.py:940, in findsource(object)
#     932 def findsource(object):
#     933     """Return the entire source file and starting line number for an object.
#     934
#     935     The argument may be a module, class, method, function, traceback, frame,
#     936     or code object.  The source code is returned as a list of all the lines
#     937     in the file and the line number indexes a line in that list.  An OSError
#     938     is raised if the source code cannot be retrieved."""
# --> 940     file = getsourcefile(object)
#     941     if file:
#     942         # Invalidate cache if needed.
#     943         linecache.checkcache(file)
#
# File ~/anaconda3/envs/EHRSHOT_ENV/lib/python3.10/inspect.py:817, in getsourcefile(object)
#     813 def getsourcefile(object):
#     814     """Return the filename that can be used to locate an object's source.
#     815     Return None if no way can be identified to get the source.
#     816     """
# --> 817     filename = getfile(object)
#     818     all_bytecode_suffixes = importlib.machinery.DEBUG_BYTECODE_SUFFIXES[:]
#     819     all_bytecode_suffixes += importlib.machinery.OPTIMIZED_BYTECODE_SUFFIXES[:]
#
# File ~/anaconda3/envs/EHRSHOT_ENV/lib/python3.10/inspect.py:786, in getfile(object)
#     784         if object.__module__ == '__main__':
#     785             raise OSError('source code not available')
# --> 786     raise TypeError('{!r} is a built-in class'.format(object))
#     787 if ismethod(object):
#     788     object = object.__func__
#
# TypeError: <class 'femr.extension.dataloader.BatchLoader'> is a built-in class
